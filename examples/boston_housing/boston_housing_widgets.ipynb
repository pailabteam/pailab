# %% [markdown]
# # MLRepo - A Quick Introduction
# In this notebook we give a quick introduction working with the repository and explain the basic priniples.

# %%
#import all things you need to get startes
import time
import pandas as pd
import logging as logging
import pprint
import plotly
plotly.offline.init_notebook_mode(connected=True)

# Here start the repository specific imports
import pailab.ml_repo.memory_handler as memory_handler
from pailab import RepoInfoKey, MeasureConfiguration, MLRepo, DataSet, MLObjectType, FIRST_VERSION, LAST_VERSION
from pailab.job_runner.job_runner import SimpleJobRunner  #, JobState

#You may set the loglevel and log-format here. 
logging.basicConfig(level=logging.FATAL)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Read the data
# As an example machine learning task to ilustrate the way of working with the repository we use the Boston housing data from the  [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.php) where we have applied some preprocessing. The data consists of house prices together with the house features `'RM'`, `'LSTAT'`, and `'PTRATIO'`:
# - `'RM'` is the average number of rooms among homes in the neighborhood.
# - `'LSTAT'` is the percentage of homeowners in the neighborhood considered "lower class" (working poor).
# - `'PTRATIO'` is the ratio of students to teachers in primary and secondary schools in the neighborhood.
# We just read the csv-file containing the data (also in the repository) into a pandas dataframe.

# %%
data = pd.read_csv('housing.csv')

# %% [markdown]
# # Create a new repository
# We first create a new repository for our task. The repository is the central key around all functionality is built. Similar to a repository used for source control in classical software development it contains all data and algorithms needed for the machine learning task. The repository needs storages for
# - scripts containing the machine learning algorithms and interfaces,
# - numerical objects such as arrays and matrices representing data, e.g. input data, data from the valuation of the models,
# - json documents representing parameters, e.g. training parameter, model parameter.
#
# To keep things simple, we just start using in memory storages. Note that the used memory interfaces are except for testing and playing around not be the first choice, since when ending the session, everything will be lost...
#
# In addition to the storages the repository needs a reference to a JobRunner which the platform can use to execute machine learning jobs. For this example we use the most simple one, executing everything sequential in the same thread, the repository runs in.

# %%
# setting up the repository
config = {'user': 'test_user',
      'workspace': 'c:/temp',
      'repo_store': 
      {
          'type': 'memory_handler',  
          'config': {}
      },
      'numpy_store':
      {
          'type': 'memory_handler',
          'config':{}
      },
      'job_runner':
      {
          'type': 'simple',
          'config': {
              'throw_job_error': True
          }
      }
    }
ml_repo = MLRepo( user = 'test_user', config=config)
job_runner = ml_repo._job_runner

# %% [markdown]
# ## Add a tree
# To navigate in a simple way over all objects, one can add a so-called tree to the repository. The tree allows one to use auto completion to acces objcts and respectiv methods.

# %%
from pailab.tools.tree import MLTree
MLTree.add_tree(ml_repo)

# %% [markdown]
# ## Adding data
# The data in the repository is handled by two different data objects:
# - RawData is the object containing real data.
# - DataSet is the object conaining the logical data, i.e. a reference to a RawData object together with a specification, which data from the RawData will be used. Here, one can specify a fixed version of the underlying RawData object (then changes to the RawData will not affect the derived DataSet) or a fixed or floating subset of the RawData by defininga start and endindex cutting the derived data just out of the original data.
#
# Normally one will add RawData and then define DataSets which are used to train or test a model which is exactly the way shown in the following.

# %%
# Add RawData. A convenient way to add RawData is to use the method add on the raw_data collection.
# This method just takes a pandas dataframe and the specification, which columns belong to the input 
#and which to the targets.
ml_repo.tree.raw_data.add('boston_housing', data,  input_variables=['RM', 'LSTAT', 'PTRATIO'], target_variables = ['MEDV'])

# based on the raw data we now define training and test sets
ml_repo.tree.training_data.add('sample1', ml_repo.tree.raw_data.boston_housing(), 0, 300)
ml_repo.tree.test_data.add('sample2', ml_repo.tree.raw_data.boston_housing(), 301, None)

# %%
ml_repo.tree.training_data.sample1.history()
# Out:
# {'83d7f948-7719-11e9-bad3-fc084a6691eb': {'RepoInfoKey.AUTHOR': 'test_user',
#   'RepoInfoKey.COMMIT_DATE': '2019-05-15 15:58:28.136788',
#   'RepoInfoKey.COMMIT_MESSAGE': ''}}

# %% [markdown]
# When creating the DataSet we have to set two important informations for the repository, given as a dictionary:
# - The object name. Each object in the repository needs to have a unique name in the repository.
# - The object type which gives. In our example here we say that we specify that the DataSet are training and test data. Note that on can have only one training data object pre repository while the repository can obtain many different test data sets.
#
# Some may wonder what is now stored in *version_list*.
# ** Adding an object (independent if it is a data object or some other object such as a parameter), the object gets a version number and no object will be removed, adding just adds a new version.** The add method returns a dictionary of the object names together with their version number.

# %% [markdown]
# ## Adding a model
# The next step to do machine learning would be to define a model which will be used in the repository. A model consists of the following pieces
# - a skript where the code for the model valuation is defined together with the function name of the evaluation method
# - a skript where the code for the model training is defined together with th function nam of the training method
# - a model parameter object defining the model parameter and which must have implemented the correct interface so that it can be used within the repository (see the documentation on integrating new objects, normally there is not more to do then just simply add *@repo_object_init()* to the line above your *__init__* method)
# - a training parameter object defining training parameters (such as number of optimization steps etc.), if necessary for your algorithms (this oen is optional)
#
# ** SKLearn models as an example**
#
# We do not have to define the pieces defined above, if we use the sklearn module. Instead we can use the pailab.externals.sklearn module interfacing
# the sklearn package so that this can be used within the repository. This interface provides a simple method (add_model) to add an arbitrary sklearn model as a model which can be handled by the repository. This method adds a bunch of repo objects to the repository (according to the pieces described above):
# - An object defining the function to be called to evaluate the model
# - An object defining the function to be called to train the model
# - An object defining the model
# - An object defining the model parameter
# For the following we just use a DecisionTree as our model.

# %%
import pailab.externals.sklearn_interface as sklearn_interface
from sklearn.tree import DecisionTreeRegressor

sklearn_interface.add_model(ml_repo, DecisionTreeRegressor(), model_param={'max_depth': 5})

# %% [markdown]
# ## Train the model
# Now, model taining is very simple, since you have defined training and testing data as well as  methods to value and fit your model and the model parameter.
# So, you can just call *run_training* on the repository, and the training is perfomred automatically.
# The training job is executed via the JobRunner you specified setting up the repository. All method of the repository involving jobs return the job id when adding the job to the JobRunner so that you can control the status of the task and see if it sucessfully finished.

# %%
job_id = ml_repo.run_training() 
print(job_id)
job_info = job_runner.get_info(job_id[0], job_id[1])
print(job_info)
# Out:
# ('DecisionTreeRegressor/jobs/training', '83f22f1a-7719-11e9-81b1-fc084a6691eb')
# test_user, successfully_finished, started 2019-05-15 15:58:28.308559, finished 2019-05-15 15:58:28.316548

# %%
# train a second time
ml_repo.run_training()
# Out:
# 'No new training started: A model has already been trained on the latest data.'

# %%
# starting training again
ml_repo.run_training()
# Out:
# 'No new training started: A model has already been trained on the latest data.'

# %% [markdown]
# ## Run evaluation
# To measure errors and to provide plots the model must be evaluated on all test and training datasets.

# %%
job_id = ml_repo.run_evaluation()
# print information about the job
info = job_runner.get_info(job_id[0][0], job_id[0][1]) 
print(str(info))
# Out:
# test_user, successfully_finished, started 2019-05-15 15:58:28.492314, finished 2019-05-15 15:58:28.496309

# %% [markdown]
# ## Add and compute measures

# %%
ml_repo.add_measure(MeasureConfiguration.MAX)
ml_repo.add_measure(MeasureConfiguration.R2)
ml_repo.add_measure(MeasureConfiguration.MSE)

# %%
job_ids = ml_repo.run_measures()

# %%
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.load()
print(str(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.obj.value))
# Out:
# 223200.0

# %% [markdown]
# Note that the steps
# - *run_evaluation*
# - *run_measures*
#
# are not necessary if *run_training* is called with the keyword argument *run_descendants=True*.
# In This case the repository would have automatically triggered all evaluations and measurement calculations automatically.

# %% [markdown]
# # Working with the repository
# This section shows how one can work with the audit and revision functionality of the repository.

# %%
from pailab.analysis.tools_jupyter import ObjectOverviewList

repo_overview = ObjectOverviewList(ml_repo)
display(repo_overview.get_widget())
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# HBox(children=(VBox(children=(SelectMultiple(options=('EVAL_DATA', 'RAW_DATA', 'TRAINING_DATA', 'TEST_DATA', '…

# %%
from pailab.analysis.tools_jupyter import ObjectView

obj_view = ObjectView(ml_repo)
display(obj_view.get_widget())
# Out:
# HBox(children=(VBox(children=(SelectMultiple(index=(16,), options=('EVAL_DATA', 'RAW_DATA', 'TRAINING_DATA', '…

# %% [markdown]
# Repository information such as version number, author, date of change are attached to the repo objects and can simply be retrieved:

# %%
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.load()
pprint.pprint(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.obj.repo_info.get_dictionary())
# Out:
# {'author': 'test_user',
#  'big_objects': [],
#  'category': 'MEASURE',
#  'classname': 'pailab.ml_repo.repo_objects.Measure',
#  'commit_date': '2019-05-15 15:58:28.628133',
#  'commit_message': 'computing  measure r2 on data sample1',
#  'description': None,
#  'modification_info': {'DecisionTreeRegressor': '83eb7ac1-7719-11e9-8248-fc084a6691eb',
#                        'DecisionTreeRegressor/eval/sample1': '840f712c-7719-11e9-92ea-fc084a6691eb',
#                        'DecisionTreeRegressor/model': '83f2cb24-7719-11e9-abf4-fc084a6691eb',
#                        'DecisionTreeRegressor/model_param': '83eb7ac0-7719-11e9-b37e-fc084a6691eb',
#                        'sample1': '83d7f948-7719-11e9-bad3-fc084a6691eb'},
#  'modifiers': {},
#  'name': 'DecisionTreeRegressor/measure/sample1/r2',
#  'version': '8422f276-7719-11e9-8b9d-fc084a6691eb'}

# %% [markdown]
# The commits can also be queried and printed.

# %%
for k in ml_repo.get_commits():
    pprint.pprint(k.to_dict())
# Out:
# {'author': 'test_user',
#  'message': 'data raw_data/boston_housing added to repository',
#  'objects': {'raw_data/boston_housing': '83d75d42-7719-11e9-b70e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 136788)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'sample1': '83d7f948-7719-11e9-bad3-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 136788)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'sample2': '83d7f949-7719-11e9-b21a-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 136788)}
# {'author': 'test_user',
#  'message': 'add function eval_sklearn of category MODEL_EVAL_FUNCTION to the '
#             'repo',
#  'objects': {'eval_sklearn': '83eade94-7719-11e9-bf9b-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 260622)}
# {'author': 'test_user',
#  'message': 'add function train_sklearn of category TRAINING_FUNCTION to the '
#             'repo',
#  'objects': {'train_sklearn': '83eade95-7719-11e9-a1a7-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 260622)}
# {'author': 'test_user',
#  'message': 'adding model and training parameter',
#  'objects': {'DecisionTreeRegressor/model_param': '83eb7ac0-7719-11e9-b37e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 264620)}
# {'author': 'test_user',
#  'message': 'add model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor': '83eb7ac1-7719-11e9-8248-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 264620)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/jobs/training': '83f22f1a-7719-11e9-81b1-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 308559)}
# {'author': 'test_user',
#  'message': 'training of model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor/model': '83f2cb24-7719-11e9-abf4-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 316548)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample2': '840e390a-7719-11e9-8606-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 492314)}
# {'author': 'test_user',
#  'message': 'evaluate data sample2 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample2': '840ed512-7719-11e9-bed2-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 496309)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample1': '840ed513-7719-11e9-9ce4-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 496309)}
# {'author': 'test_user',
#  'message': 'evaluate data sample1 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample1': '840f712c-7719-11e9-92ea-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 500305)}
# {'author': 'test_user',
#  'message': 'added measure max for coordinates all',
#  'objects': {'measure_config': '8416c194-7719-11e9-bb6e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 548238)}
# {'author': 'test_user',
#  'message': 'added measure r2 for coordinates all',
#  'objects': {'measure_config': '8416c195-7719-11e9-ab4c-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 548238)}
# {'author': 'test_user',
#  'message': 'added measure mse for coordinates all',
#  'objects': {'measure_config': '8416c196-7719-11e9-8caf-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 548238)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/max': '841fe638-7719-11e9-988f-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 608159)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/max': '84208246-7719-11e9-b996-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 612154)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/r2': '84208247-7719-11e9-9a2a-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 616148)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/r2': '84211e50-7719-11e9-b5b5-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 616148)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/mse': '8421ba5c-7719-11e9-8038-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 620143)}
# {'author': 'test_user',
#  'message': 'computing  measure mse on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/mse': '8421ba5d-7719-11e9-8d36-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 620143)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/max': '8422566c-7719-11e9-ad3a-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 624138)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/max': '8422566d-7719-11e9-95cb-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 624138)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/r2': '8422566e-7719-11e9-8430-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 624138)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/r2': '8422f276-7719-11e9-8b9d-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 628133)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/mse': '8422f277-7719-11e9-9a6b-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 628133)}
# {'author': 'test_user',
#  'message': 'computing  measure mse on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/mse': '84238e76-7719-11e9-b020-fc084a6691eb'},
#  'time': datetime.datetime(2019, 5, 15, 15, 58, 28, 632127)}

# %% [markdown]
# ## Labeling models
# There is the possibility to label a certain version of a model. The label can then be used to access the model instead of the version number. It is vry useful to
# compare e.g. the current productive model (labeld e.g. 'prod') against other model versions. abels are supported by many functions and tools and make life much easier. So the consistency checks only check for the latest and labeled models if there are changes make a rerun of training/evaluation/measures needed. Also som figures will automatically highlight the results belonging to labeled versions.
#
# Let us label the latest model version in the repo.

# %%
ml_repo.tree.models.DecisionTreeRegressor.set_label('prod',version = LAST_VERSION, message='we found our first production model')

# %% [markdown]
# ## Tests
# It is possible to define model tests.
# ### Regressiontests
# Regressiontests compare measuresments on the repositories dataset of a model to th measurements of labeled reference model.

# %%
import pailab.tools.tests
reg_test = pailab.tools.tests.RegressionTestDefinition(reference='prod', models=None, data=None, labels=None, measures=None,  tol=1e-3)

reg_test.repo_info.name='reg_test'
#reg_test.repo_info.category = MLObjectType.TEST_DEFINITION
ml_repo.add(reg_test, message='regression test definition')
#ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.
# Out:
# '846b7b9a-7719-11e9-b0be-fc084a6691eb'

# %%
ml_repo.run_tests()
# Out:
# [('DecisionTreeRegressor/tests/reg_test/sample2',
#   '847367f4-7719-11e9-992f-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '847367f5-7719-11e9-8f48-fc084a6691eb')]

# %% [markdown]
# ## Consistency checks
# Pailab's *checks*-submodule provides functionality to check for consistency and quality issues as well as for outstanding tasks (such as rerunning a training after the training set has been changed).
#
# ### Model consistency
# There are different checks to test model consistency such as if the tests of a model are up to date and succeeded or if the latest model is trained on the latest trainin data. All model tests are performed for **labeled** models and the latest model only.
# In our first example we change a model parameter but do not train for a new model version wih this parameter.
#
# The following checks are performed:
# - Is the latest model calibrated on the latest parameters and training data
# - Are all labeled models (including latest model) evaluated on the latest available training and test data
# - Are all measures of all labeled models computed on the latest data
# - Have all tests been run on the labeled models

# %%
param = ml_repo.get('DecisionTreeRegressor/model_param')
param.sklearn_params['max_depth'] = 2
version = ml_repo.add(param)
print(param.sklearn_params)
# Out:
# {'criterion': 'mse', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': False, 'random_state': None, 'splitter': 'best'}

# %% [markdown]
# After we have changed the model parameter, we use the *tools* submodules *check_model* method for open tasks/inconsistencies. This method can be called for a certain model or also for a lbeled model. If nothing is specified, all labeled models will be checked.
# Applying the method to the latest model we see that the output shows that the models last version has been calibrated using a different model parameter version then the current version.

# %%
from pailab.analysis.tools_jupyter import ConsistencyChecker

consistency_checker = ConsistencyChecker(ml_repo)
display(consistency_checker.get_widget())
# Out:
# VBox(children=(Button(description='update', style=ButtonStyle()), Output()))

# %% [markdown]
# Note that the labeled model would not show an issue. Only the latest model is affected by this change (it is the definition of latest model that it has been calibrated on latest inputs).
#
# We can resolve this issue by simply training the model again (now on the new training data set).

# %%
ml_repo.run_training()
# Out:
# ('DecisionTreeRegressor/jobs/training', '848f71da-7719-11e9-afa6-fc084a6691eb')

# %% [markdown]
# Note that the solution to simply retrain introduced new issues: The model has not yet been evaluated and no measures have been computed. (If we would have set **run_descendants=False** as argument, the preceding steps would have also been performed and the issues would not have been present).

# %%
ml_repo.run_evaluation(run_descendants=True)# we use run_descendants so that the issues with th measures are resolved too
# Out:
# [('DecisionTreeRegressor/model/jobs/eval_job/sample2',
#   '8497fb9e-7719-11e9-b233-fc084a6691eb'),
#  ('DecisionTreeRegressor/model/jobs/eval_job/sample1',
#   '849b069e-7719-11e9-b3bb-fc084a6691eb')]

# %%
ml_repo.run_tests()
# Out:
# [('DecisionTreeRegressor/tests/reg_test/sample2',
#   '84a69b80-7719-11e9-804a-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '84a7378c-7719-11e9-a0b4-fc084a6691eb')]

# %%
ml_repo.tree.test_data.add('sample3', ml_repo.tree.raw_data.boston_housing(), 0, 50)

# %% [markdown]
# ## Append RawData
# One can append data to the RawData object. The repository manages which objects are affected by appending data and directly updates these objects.

# %%
train_data = ml_repo.get_training_data(full_object = False)
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data) +' Version: '+str(train_data.repo_info.version))
test_data = ml_repo.get_names(MLObjectType.TEST_DATA)
for k in test_data:
    t = ml_repo.get(k)
    print('')
    print(str(k) + ': ' + str(t)+ ' Version: ' + str(t.repo_info.version))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 83d7f948-7719-11e9-bad3-fc084a6691eb
#
# sample2: {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 83d7f949-7719-11e9-b21a-fc084a6691eb
#
# sample3: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 84afc00c-7719-11e9-87ab-fc084a6691eb

# %%
from numpy import array
ml_repo.tree.raw_data.boston_housing.append(x_data = array([[ 6.575, 4.98, 15.3]]), y_data =array([[504000.0]]))

# %%
train_data = ml_repo.get_training_data(full_object = False)
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data) +' Version: '+str(train_data.repo_info.version))
test_data = ml_repo.get_names(MLObjectType.TEST_DATA)
for k in test_data:
    t = ml_repo.get(k)
    print('')
    print(str(k) + ': ' + str(t)+ ' Version: ' + str(t.repo_info.version))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 83d7f948-7719-11e9-bad3-fc084a6691eb
#
# sample2: {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': '84c03540-7719-11e9-a263-fc084a6691eb', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 84c0d13a-7719-11e9-92a0-fc084a6691eb
#
# sample3: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 84afc00c-7719-11e9-87ab-fc084a6691eb

# %% [markdown]
# # Repo-Analysis
# Having parameters, evaluations, measures in one place enables out of the box analysis- and plotting functionality. The submodule *plot* provides automated, standardized plots.

# %%
import pailab.analysis.plot as plot

# %% [markdown]
# ## Plotting
# ### Plot errors and measures

# %%
# create more different model params etc. to make the repo more interesting ;-)
for j in range(2):
    training_data = ml_repo.get(ml_repo.tree.training_data.sample1())
    training_data.end_index += 50
    ml_repo.add(training_data, message='add 50 datapoints to end_index')
    for i in range(6,12):
        #print(i)
        param = ml_repo.get(ml_repo.tree.models.DecisionTreeRegressor.model_param())
        param.sklearn_params['max_depth'] = i
        version = ml_repo.add(param)
        ml_repo.add(param)
        ml_repo.run_training()
        ml_repo.run_evaluation()
        ml_repo.run_measures()
        if j == 1 and i==6:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('prod', message='')
        if j == 1 and i==8:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('candidate', message='')

# %% [markdown]
# #### Plot error measure vs parameter

# %%
import pailab.analysis.plot_helper as plt_helper
import pailab.analysis.plot as plot
plot.measure_by_parameter(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.measures('max'), 'max_depth', data_versions=LAST_VERSION)
ml_repo.tree.models.DecisionTreeRegressor.measures('r2')
# Out:
# <div>
#
#
#             <div id="be40cae6-dacb-4adb-94de-dbfa3d7de652" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("be40cae6-dacb-4adb-94de-dbfa3d7de652")) {
#                     Plotly.newPlot(
#                         'be40cae6-dacb-4adb-94de-dbfa3d7de652',
#                         [{"mode": "markers", "name": "DecisionTreeRegressor/measure/sample2/max: 84c0d13a-7719-11e9-92a0-fc084a6691eb", "text": ["model version: 84d7facd-7719-11e9-9a34-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 84d75ec8-7719-11e9-b375-fc084a6691eb", "model version: 83f2cb24-7719-11e9-abf4-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 83d7f948-7719-11e9-bad3-fc084a6691eb", "model version: 84e563b8-7719-11e9-958b-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 84d75ec8-7719-11e9-b375-fc084a6691eb", "model version: 84edec62-7719-11e9-bc17-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 84d75ec8-7719-11e9-b375-fc084a6691eb", "model version: 84f4a0d8-7719-11e9-af7c-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 84d75ec8-7719-11e9-b375-fc084a6691eb", "model version: 84fdc568-7719-11e9-8f99-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 84d75ec8-7719-11e9-b375-fc084a6691eb", "model version: 85078610-7719-11e9-9303-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 84d75ec8-7719-11e9-b375-fc084a6691eb", "model version: 8511e2da-7719-11e9-a641-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 851d77e9-7719-11e9-b60b-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 85269c2e-7719-11e9-a96b-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 85319506-7719-11e9-a547-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 853b55c2-7719-11e9-8f00-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 85451654-7719-11e9-b144-fc084a6691eb<br>sample3: 84c0d13a-7719-11e9-92a0-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb"], "type": "scatter", "uid": "5c92ddcf-72a7-4b9d-9329-e199c8303cfc", "x": [6, 5, 7, 8, 9, 10, 11, 6, 7, 8, 9, 10, 11], "y": [400050.0, 415450.0, 342300.0, 336000.0, 342300.0, 342300.0, 342300.0, 407400.0, 407400.0, 401100.0, 407400.0, 407400.0, 401100.0]}, {"mode": "markers", "name": "DecisionTreeRegressor/measure/sample1/max: 851146d0-7719-11e9-ae8c-fc084a6691eb", "text": ["model version: 8511e2da-7719-11e9-a641-fc084a6691eb<br>sample3: 851146d0-7719-11e9-ae8c-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 83f2cb24-7719-11e9-abf4-fc084a6691eb<br>sample3: 851146d0-7719-11e9-ae8c-fc084a6691eb<br>train_data: 83d7f948-7719-11e9-bad3-fc084a6691eb", "model version: 851d77e9-7719-11e9-b60b-fc084a6691eb<br>sample3: 851146d0-7719-11e9-ae8c-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 85269c2e-7719-11e9-a96b-fc084a6691eb<br>sample3: 851146d0-7719-11e9-ae8c-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 85319506-7719-11e9-a547-fc084a6691eb<br>sample3: 851146d0-7719-11e9-ae8c-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 853b55c2-7719-11e9-8f00-fc084a6691eb<br>sample3: 851146d0-7719-11e9-ae8c-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb", "model version: 85451654-7719-11e9-b144-fc084a6691eb<br>sample3: 851146d0-7719-11e9-ae8c-fc084a6691eb<br>train_data: 851146d0-7719-11e9-ae8c-fc084a6691eb"], "type": "scatter", "uid": "0b2627a6-146e-4777-8fe3-d8eda53905ba", "x": [6, 5, 7, 8, 9, 10, 11], "y": [182100.0, 415450.0, 170730.0, 160883.3333333333, 165900.0, 159096.0, 116200.0]}, {"mode": "markers", "name": "DecisionTreeRegressor/measure/sample3/max: 84afc00c-7719-11e9-87ab-fc084a6691eb", "text": ["model version: 84d7facd-7719-11e9-9a34-fc084a6691eb<br> ...
#                         {"annotations": [{"arrowhead": 2, "showarrow": true, "text": "prod", "x": 6, "xref": "x", "y": 407400.0, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "candidate", "x": 8, "xref": "x", "y": 401100.0, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "prod", "x": 6, "xref": "x", "y": 182100.0, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "candidate", "x": 8, "xref": "x", "y": 160883.3333333333, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "prod", "x": 6, "xref": "x", "y": 150757.89473684208, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "candidate", "x": 8, "xref": "x", "y": 113531.25, "yref": "y"}], "title": {"text": "measure by parameter"}, "xaxis": {"title": {"text": "max_depth"}}, "yaxis": {"title": {"text": "max"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('be40cae6-dacb-4adb-94de-dbfa3d7de652');
# var x = new Mut
# ['DecisionTreeRegressor/measure/sample2/r2',
#  'DecisionTreeRegressor/measure/sample1/r2',
#  'DecisionTreeRegressor/measure/sample3/r2']

# %%
#
from pailab.analysis.tools_jupyter import Plotter
plotter = Plotter(ml_repo)
display(plotter.get_widget())
# Out:
# VBox(children=(HBox(children=(Button(description='plot', style=ButtonStyle()), SelectMultiple(options=('Decisi…

# %%
ml_repo.get_names(MLObjectType.MODEL_PARAM)
# Out:
# ['DecisionTreeRegressor/model_param']

# %% [markdown]
# #### Plot error vs input variable

# %%
import pailab.analysis.plot as plot
plot.scatter_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ['sample1', ml_repo.tree.test_data.sample2()], 'PTRATIO')
# Out:
# <div>
#
#
#             <div id="8f5a421c-26b6-41c1-8d0b-c8caecdecf2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8f5a421c-26b6-41c1-8d0b-c8caecdecf2a")) {
#                     Plotly.newPlot(
#                         '8f5a421c-26b6-41c1-8d0b-c8caecdecf2a',
#                         [{"mode": "markers", "name": "prod, DecisionTreeRegressor/eval/sample1: 85158afe-7719-11e9-89dd-fc084a6691eb", "text": "sample1:last<br>DecisionTreeRegressor/model:8511e2da-7719-11e9-a641-fc084a6691eb<br>", "type": "scatter", "uid": "36799e79-d875-4ca1-a022-2a934aa20924", "x": [15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7, 18.7, 18.7, 18.7, 19.0, 19.0, 19.0, 19.0, 18.5, 18.5, 18.5, 18.5, 17.8, 17.8, 17.8, 17.8, 18.2, 18.2, 18.2, 18.0, 18.0, 18.0, 18.0, 18.0, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.6, 15.6, 12.6, 12.6, 12.6, 17.0, 17.0, 14.7, 14.7, 14.7, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 16.4, 16.4, 16.4, 16.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 16.4, 16.4, 15.9, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 18.6, 18.6, 18.6, 18.6, 18.6, 17.6, 17.6, 17.6, 17.6, 17.6, 14.9, 14.9, 14.9, 14.9, 15.3, 15.3, 18.2, 16.6, 16.6, 16.6, 19.2, 19.2, 19.2, 16.0, 16.0, 16.0, 16.0, 16.0, 14.8, 14.8, 14.8, 16.1, 16.1, 16.1, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2], "y": [-60738.4615384615, -42329.4117647059, 7665.0, -19635.0, 39165.0, 106770.5882352941, 36554.23728813557, 150757.89473684208, 0.0, -21442.105263157922, 0.0, -47445.76271186443, 11354.23728813557, -15711.111111111124, -38107.317073170736, -26211.111111111124, 40988.888888888876, -2672.727272727294, 3892.682926829264, -38107.317073170736, 1500.0, -8707.317073170736, -25725.0, 0.0, -17325.0, -13020.0, -21572.727272727294, -34125.0, -33907.317073170736, 0.0, -17400.0, -115807.31707317074, -6900.0, -29820.0, -600.0, -23407.317073170736, -307.31707317073597, -3111.111111111124, 98392.68292682926, -16100.0, 11865.0, -6138.461538461503, 35370.5882352941, 22770.588235294097, 1088.888888888876, -39045.76271186443, -24345.76271186443, -69742.10526315792, 0.0, -10942.105263157922, -30645.76271186443, -13611.111111111124, 29070.588235294097, 47288.888888888876, 26727.272727272706, 22365.0, 22770.588235294097, 7350.0, -6629.411764705903, -32511.111111111124, -27607.317073170736, -34172.727272727294, -29729.411764705903, -38010.0, -8400.0, -2429.411764705903, -36945.76271186443, 17888.888888888876, -54907.317073170736, -5211.111111111124, 12270.588235294097, 35392.682926829264, 34688.888888888876, -4529.411764705903, 10170.588235294097, -46529.4117647059, -24345.76271186443, -7545.762711864430 ...

# %% [markdown]
# #### Plot histogram of model error

# %%
plot.histogram_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ml_repo.tree.test_data.sample2())
# Out:
# <div>
#
#
#             <div id="e55ca504-f8da-4755-be36-b6f373f52fac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e55ca504-f8da-4755-be36-b6f373f52fac")) {
#                     Plotly.newPlot(
#                         'e55ca504-f8da-4755-be36-b6f373f52fac',
#                         [{"histnorm": "percent", "name": "prod, DecisionTreeRegressor/eval/sample2: 85131af6-7719-11e9-a648-fc084a6691eb", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:8511e2da-7719-11e9-a641-fc084a6691eb<br>", "type": "histogram", "uid": "831b77c0-ae8d-426f-b1d8-f340702d78a1", "x": [-36945.76271186443, -42329.4117647059, -8400.0, -104145.76271186443, -44542.10526315792, -28545.76271186443, 40754.23728813557, -3345.7627118644305, 3870.588235294097, -10829.411764705903, -15711.111111111124, -31807.317073170736, 29070.588235294097, 20670.588235294097, -12929.411764705903, 45892.682926829264, -39045.76271186443, -21329.411764705903, -80129.4117647059, -85245.76271186443, -36711.111111111124, -29729.411764705903, -61229.4117647059, -1011.111111111124, -10807.317073170736, -31807.317073170736, -11511.111111111124, -21307.317073170736, -51411.111111111124, -14700.0, -149429.4117647059, -61110.0, -1050.0, -52807.317073170736, -59107.317073170736, -10829.411764705903, -50238.4615384615, 28875.0, -15029.411764705903, -58638.4615384615, -53511.111111111124, 10500.0, -61911.111111111124, -11511.111111111124, 28875.0, 35392.682926829264, 56392.682926829264, 54292.682926829264, 29070.588235294097, -2407.317073170736, 16492.682926829264, -17372.727272727294, 0.0, 39592.682926829264, 64792.682926829264, 96000.0, 96000.0, 0.0, 50505.0, 37905.0, 33705.0, -27195.0, 0.0, -12495.0, -4095.0, 16905.0, -9000.0, -42600.0, 26700.0, -38400.0, 20400.0, 105.0, 12180.0, 0.0, -37695.0, -80372.7272727273, -78225.0, -69825.0, 21105.0, -62895.0, -88800.0, -61500.0, -76200.0, -90195.0, 12705.0, -67095.0, -15300.0, -136395.0, 8505.0, 165592.68292682926, 119805.0, 0.0, -105307.31707317074, 119805.0, 182100.0, 100905.0, -46800.0, -42600.0, -83895.0, 24600.0, -56595.0, -401100.0, -19472.727272727294, -71972.7272727273, 16492.682926829264, 40005.0, -59220.0, -67095.0, -155972.7272727273, -141272.7272727273, -10395.0, -41895.0, -40425.0, -281400.0, -82207.31707317074, -44625.0, -124472.7272727273, 40005.0, -143325.0, -58695.0, -17400.0, 27405.0, -20895.0, 117705.0, 41475.0, -163800.0, -14595.0, 6405.0, -32025.0, -80325.0, -48825.0, 31605.0, -63525.0, -25725.0, -6825.0, 58800.0, -32025.0, -48825.0, -220500.0, -61425.0, -32025.0, 49827.272727272706, -525.0, 1527.272727272706, -10807.317073170736, 3892.682926829264, 29092.682926829264, -2407.317073170736, 54075.0, 159705.0, 56175.0, 51927.272727272706, 72975.0, -8707.317073170736, 66892.68292682926, 407400.0, -15120.0, 37905.0, 5775.0, 10605.0, -38325.0, 29092.682926829264, 62692.682926829264, -65310.0, 306600.0, 37492.682926829264, 12292.682926829264, 24892.682926829264, 30927.272727272706, 12292.682926829264, 14280.0, -94395.0, -23700.0, -59325.0, 1792.682926829264, 37492.682926829264, 94192.68292682926, 66757.89473684208, -4642.105263157922, -36007.317073170736, 24892.682926829264, -2672.727272727294, -67507.31707317074, -37800.0, -11511.111111111124, 283500.0, -102738.4615384615]}, {"histnorm": "percent", "name": "candidate, DecisionTreeRegressor/eval/sample2: 85287054-7719-11e9-b73c-fc084a6691eb", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:85269c2e-7719-11e9-a96b-fc084a6691eb<br>", "type": "histogram", "uid": "51c81f8b-7761-479b-a158-4401dafb4469", "x": [-53316.666666666686, -19472.727272727294, -3500.0, -85350.0, -31005.882352941204, -18200.0, 24383.333333333314, -19716.666666666686, -6407.692307692312, -21107.692307692312, 2100.0, -29531.25, 18792.307692307688, 10392.307692307688, -23207.692307692312, 48168.75, -20250.0, -31607.692307692312, -57272.727272727294, -66450.0, -18900.0, -40007.69230769231, -71507.69230769231, 16800.0, -8531.25, -29531.25, 6300.0, -19031.25, -33600.0, -35466.66666666663, 0.0, 0.0, 1050.0, 0.0, -2100.0, -21107.692307692312, -41790.0, -9450.0, -25307.692307692312, -50190.0, -35700.0, 0.0, -44100.0, 6300.0, 0.0, 37668.75, 58668.75, 56568.75, 18792.307692307688, -131.25, -23450.0, 26600.0, 0.0, -350.0, 24850.0, 14175.0, 141 ...
#                         {"barmode": "overlay", "title": {"text": "pointwise error (MEDV)"}, "xaxis": {"title": {"text": "model-target  [MEDV]"}}},
#                         {"showLink": false, "linkText": "Expo

# %% [markdown]
# ### Plot data

# %%
plot.histogram_data(ml_repo, {ml_repo.tree.test_data.sample2() :['last'], ml_repo.tree.training_data.sample1(): ['first','last']}, x_coordinate = 'PTRATIO') #, y_coordinate='MEDV')
# Out:
# <div>
#
#
#             <div id="33eea752-a3a1-4bc1-a4ca-f3b045f869da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("33eea752-a3a1-4bc1-a4ca-f3b045f869da")) {
#                     Plotly.newPlot(
#                         '33eea752-a3a1-4bc1-a4ca-f3b045f869da',
#                         [{"histnorm": "percent", "name": "sample2: 84c0d13a-7719-11e9-92a0-fc084a6691eb", "opacity": 0.5, "text": "", "type": "histogram", "uid": "1da700af-5a88-419b-828b-09185bbe447e", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0, 21.0, 21.0]}, {"histnorm": "percent", "name": "sample1: 83d7f948-7719-11e9-bad3-fc084a6691eb", "opacity": 0.5, "text": "", "type": "histogram", "uid": "3758d5c0-9cd4-46cf-af18-4deb80d315d5", "x": [15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7, 18.7, 18.7, 18.7, 19.0, 19.0, 19.0, 19.0, 18.5, 18.5, 18.5, 18.5, 17.8, 17.8, 17.8, 17.8, 18.2, 18.2, 18.2, 18.0, 18.0, 18.0, 18.0, 18.0, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.6, 15.6, 12.6, 12.6, 12.6, 17.0, 17.0, 14.7, 14.7, 14.7, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 16.4, 16.4, 16.4, 16.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 16.4, 16.4, 15.9, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 18.6, 18.6, 18.6, 18.6, 18.6, 17.6, 17.6, 17.6, 17.6, 17.6, 14.9, 14.9, 14.9, 14.9, 15.3, 15.3, 18.2, 16.6, 16.6, 16.6, 19.2, 19.2, 19.2, 16.0, 16.0, 16.0, 16.0, 16.0, 14.8, 14.8, 14.8, 16.1, 16.1, 16.1, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4]}, {"histnorm": "percent", "name": "sample1: 851146d0-7719-11e9-ae8c-fc084a6691eb", "opacity": 0.5, "text": "", "type": "histogram", "uid": "28f403b1-01bc-42d7-bd21-e2d1014af1e5", "x": [15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7, 18.7, 18.7, 18.7, 19.0, 19.0, 19.0, 19.0, 18 ...
#                         {"barmode": "overlay", "title": {"text": "data distribution"}, "xaxis": {"title": {"text": "PTRATIO"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('33eea752-a3a1-4bc1-a4ca-f3b045f869da');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ### Plot projections

# %%
data_1 = ml_repo.get('sample1', full_object = True)
left = data_1.x_data[0,:]
right = data_1.x_data[10,:]
output_index = 0
plot.projection(ml_repo, left = left, right=right, n_steps = 100, output_index = output_index)
# Out:
# <div>
#
#
#             <div id="ffb563b4-4650-4079-96b3-de870364bc6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ffb563b4-4650-4079-96b3-de870364bc6e")) {
#                     Plotly.newPlot(
#                         'ffb563b4-4650-4079-96b3-de870364bc6e',
#                         [{"name": "prod", "type": "scatter", "uid": "7906b8d1-0977-4adc-95f4-4da24c4ca4f7", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.050505050505050504, 0.06060606060606061, 0.0707070707070707, 0.08080808080808081, 0.09090909090909091, 0.10101010101010101, 0.1111111111111111, 0.12121212121212122, 0.13131313131313133, 0.1414141414141414, 0.15151515151515152, 0.16161616161616163, 0.1717171717171717, 0.18181818181818182, 0.1919191919191919, 0.20202020202020202, 0.21212121212121213, 0.2222222222222222, 0.23232323232323232, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.2727272727272727, 0.2828282828282828, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.3333333333333333, 0.3434343434343434, 0.35353535353535354, 0.36363636363636365, 0.37373737373737376, 0.3838383838383838, 0.3939393939393939, 0.40404040404040403, 0.41414141414141414, 0.42424242424242425, 0.43434343434343436, 0.4444444444444444, 0.45454545454545453, 0.46464646464646464, 0.47474747474747475, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515151, 0.5252525252525253, 0.5353535353535354, 0.5454545454545454, 0.5555555555555556, 0.5656565656565656, 0.5757575757575758, 0.5858585858585859, 0.5959595959595959, 0.6060606060606061, 0.6161616161616161, 0.6262626262626263, 0.6363636363636364, 0.6464646464646465, 0.6565656565656566, 0.6666666666666666, 0.6767676767676768, 0.6868686868686869, 0.696969696969697, 0.7070707070707071, 0.7171717171717171, 0.7272727272727273, 0.7373737373737373, 0.7474747474747475, 0.7575757575757576, 0.7676767676767676, 0.7777777777777778, 0.7878787878787878, 0.797979797979798, 0.8080808080808081, 0.8181818181818182, 0.8282828282828283, 0.8383838383838383, 0.8484848484848485, 0.8585858585858586, 0.8686868686868687, 0.8787878787878788, 0.8888888888888888, 0.898989898989899, 0.9090909090909091, 0.9191919191919192, 0.9292929292929293, 0.9393939393939394, 0.9494949494949495, 0.9595959595959596, 0.9696969696969697, 0.9797979797979798, 0.98989898989899, 1.0], "y": [564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 564738.4615384615, 508200.0, 508200.0, 508200.0, 508200.0, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 578340.0, 578340.0, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 444345.76271186443, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0, 315000.0]}, {"name": "candidate", "type": "scatter", "uid": "ddd6d7dd-a0c7-4ed3-8097-f00c2e28a2da", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.050505050505050504, 0.06060606060606061, 0.0707070 ...

# %%
plot.histogram_data_conditional_error(ml_repo,  ml_repo.tree.models.DecisionTreeRegressor.model(),ml_repo.tree.test_data.sample2(), x_coordinate = 'PTRATIO')
# Out:
# <div>
#
#
#             <div id="c82fa44f-2d78-4c6f-b85a-c75c25353bf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c82fa44f-2d78-4c6f-b85a-c75c25353bf9")) {
#                     Plotly.newPlot(
#                         'c82fa44f-2d78-4c6f-b85a-c75c25353bf9',
#                         [{"histnorm": "percent", "name": "prod:0.1", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:8511e2da-7719-11e9-a641-fc084a6691eb<br>", "type": "histogram", "uid": "a67286a7-b976-4803-943a-4686de1f93bf", "x": [20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 21.0, 20.2, 20.2, 20.2]}, {"histnorm": "percent", "name": "prod", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:8511e2da-7719-11e9-a641-fc084a6691eb<br>", "type": "histogram", "uid": "55f67c57-356e-4d01-b833-4c6702afc341", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0, 21.0]}, {"histnorm": "percent", "name": "candidate:0.1", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:85269c2e-7719-11e9-a96b-fc084a6691eb<br>", "type": "histogram", "uid": "ee578fd3-a124-4dbd-b51b-b0bdaefafb3f", "x": [20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 21.0, 20.2, 20.2, 20.2, 20.2, 20.2]}, {"histnorm": "percent", "name": "candidate", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:85269c2e-7719-11e9-a96b-fc084a6691eb<br>", "type": "histogram", "uid": "a0b5fc6d-050a-4a23-be0e-749687015da8", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0, 21.0]}, {"histnorm": "percent", "name": "DecisionTreeRegressor/eval/sample2: 85464e65-7719-11e9-9ada-fc084a6691eb:0.1", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:85451654-7719-11e9-b144-fc084a6691eb<br>", "type": "histogram", "uid": "34594fab-5b7a-4d15-99cd-449e6efc13fe", "x": [20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 21.0, 20.2, 20.2, 20.2, 20.2, 20.2]}, {"histnorm": "percent", "name": "DecisionTreeRegressor/eval/sample2: 85464e65-7719-11e9-9ada-fc084a6691eb", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/ ...
#                         {"barmode": "overlay", "title": {"text": ""}, "xaxis": {"title": {"text": "PTRATIO"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c82fa44f-2d78-4c6f-b85a-c75c25353bf9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
