# %% [markdown]
# # MLRepo - A Quick Introduction
# In this notebook we give a quick introduction working with the repository and explain the basic priniples.

# %%
#import all things you need to get startes
import time
import pandas as pd
import logging as logging
import pprint
import plotly
plotly.offline.init_notebook_mode(connected=True)

# Here start the repository specific imports
import pailab.memory_handler as memory_handler
from pailab import RepoInfoKey, MeasureConfiguration, MLRepo, DataSet, MLObjectType, FIRST_VERSION, LAST_VERSION
from pailab.job_runner.job_runner import SimpleJobRunner  #, JobState

#You may set the loglevel and log-format here. 
logging.basicConfig(level=logging.FATAL)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Read the data
# As an example machine learning task to ilustrate the way of working with the repository we use the Boston housing data from the  [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.php) where we have applied some preprocessing. The data consists of house prices together with the house features `'RM'`, `'LSTAT'`, and `'PTRATIO'`:
# - `'RM'` is the average number of rooms among homes in the neighborhood.
# - `'LSTAT'` is the percentage of homeowners in the neighborhood considered "lower class" (working poor).
# - `'PTRATIO'` is the ratio of students to teachers in primary and secondary schools in the neighborhood.
# We just read the csv-file containing the data (also in the repository) into a pandas dataframe.

# %%
data = pd.read_csv('housing.csv')

# %% [markdown]
# # Create a new repository
# We first create a new repository for our task. The repository is the central key around all functionality is built. Similar to a repository used for source control in classical software development it contains all data and algorithms needed for the machine learning task. The repository needs storages for
# - scripts containing the machine learning algorithms and interfaces,
# - numerical objects such as arrays and matrices representing data, e.g. input data, data from the valuation of the models,
# - json documents representing parameters, e.g. training parameter, model parameter.
#
# To keep things simple, we just start using in memory storages. Note that the used memory interfaces are except for testing and playing around not be the first choice, since when ending the session, everything will be lost...
#
# In addition to the storages the repository needs a reference to a JobRunner which the platform can use to execute machine learning jobs. For this example we use the most simple one, executing everything sequential in the same thread, the repository runs in.

# %%
handler = memory_handler.RepoObjectMemoryStorage() 
numpy_handler = memory_handler.NumpyMemoryStorage()
 
ml_repo = MLRepo( user = 'test_user', config=None, numpy_repo=numpy_handler)
job_runner = ml_repo._job_runner

# %% [markdown]
# ## Add a tree
# To navigate in a simple way over all objects, one can add a so-called tree to the repository. The tree allows one to use auto completion to acces objcts and respectiv methods.

# %%
from pailab.tools.tools import MLTree
MLTree.add_tree(ml_repo)

# %% [markdown]
# ## Adding data
# The data in the repository is handled by two different data objects:
# - RawData is the object containing real data.
# - DataSet is the object conaining the logical data, i.e. a reference to a RawData object together with a specification, which data from the RawData will be used. Here, one can specify a fixed version of the underlying RawData object (then changes to the RawData will not affect the derived DataSet) or a fixed or floating subset of the RawData by defininga start and endindex cutting the derived data just out of the original data.
#
# Normally one will add RawData and then define DataSets which are used to train or test a model which is exactly the way shown in the following.

# %%
# Add RawData. A convenient way to add RawData is to use the method add on the raw_data collection.
# This method just takes a pandas dataframe and the specification, which columns belong to the input 
#and which to the targets.
ml_repo.tree.raw_data.add('boston_housing', data,  input_variables=['RM', 'LSTAT', 'PTRATIO'], target_variables = ['MEDV'])

# based on the raw data we now define training and test sets
ml_repo.tree.training_data.add('sample1', ml_repo.tree.raw_data.boston_housing(), 0, 300)
ml_repo.tree.test_data.add('sample2', ml_repo.tree.raw_data.boston_housing(), 301, None)

# %%
ml_repo.tree.training_data.sample1.history()
# Out:
# {'0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb': {'RepoInfoKey.AUTHOR': 'test_user',
#   'RepoInfoKey.COMMIT_DATE': '2019-03-01 17:14:07.517359',
#   'RepoInfoKey.COMMIT_MESSAGE': ''}}

# %% [markdown]
# When creating the DataSet we have to set two important informations for the repository, given as a dictionary:
# - The object name. Each object in the repository needs to have a unique name in the repository.
# - The object type which gives. In our example here we say that we specify that the DataSet are training and test data. Note that on can have only one training data object pre repository while the repository can obtain many different test data sets.
#
# Some may wonder what is now stored in *version_list*.
# ** Adding an object (independent if it is a data object or some other object such as a parameter), the object gets a version number and no object will be removed, adding just adds a new version.** The add method returns a dictionary of the object names together with their version number.

# %% [markdown]
# ## Adding a model
# The next step to do machine learning would be to define a model which will be used in the repository. A model consists of the following pieces
# - a skript where the code for the model valuation is defined together with the function name of the evaluation method
# - a skript where the code for the model training is defined together with th function nam of the training method
# - a model parameter object defining the model parameter and which must have implemented the correct interface so that it can be used within the repository (see the documentation on integrating new objects, normally there is not more to do then just simply add *@repo_object_init()* to the line above your *__init__* method)
# - a training parameter object defining training parameters (such as number of optimization steps etc.), if necessary for your algorithms (this oen is optional)
#
# ** SKLearn models as an example**
#
# We do not have to define the pieces defined above, if we use the sklearn module. Instead we can use the pailab.externals.sklearn module interfacing
# the sklearn package so that this can be used within the repository. This interface provides a simple method (add_model) to add an arbitrary sklearn model as a model which can be handled by the repository. This method adds a bunch of repo objects to the repository (according to the pieces described above):
# - An object defining the function to be called to evaluate the model
# - An object defining the function to be called to train the model
# - An object defining the model
# - An object defining the model parameter
# For the following we just use a DecisionTree as our model.

# %%
import pailab.externals.sklearn_interface as sklearn_interface
from sklearn.tree import DecisionTreeRegressor

sklearn_interface.add_model(ml_repo, DecisionTreeRegressor(), model_param={'max_depth': 5})

# %% [markdown]
# ## Train the model
# Now, model taining is very simple, since you have defined training and testing data as well as  methods to value and fit your model and the model parameter.
# So, you can just call *run_training* on the repository, and the training is perfomred automatically.
# The training job is executed via the JobRunner you specified setting up the repository. All method of the repository involving jobs return the job id when adding the job to the JobRunner so that you can control the status of the task and see if it sucessfully finished.

# %%
job_id = ml_repo.run_training() 
print(job_id)
job_info = job_runner.get_info(job_id[0], job_id[1])
print(job_info)
# Out:
# ('DecisionTreeRegressor/jobs/training', '0a6b10ae-3c3d-11e9-85fe-fc084a6691eb')
# test_user, successfully_finished, started 2019-03-01 17:14:07.697118, finished 2019-03-01 17:14:07.701114

# %%
# train a second time
ml_repo.run_training()
# Out:
# 'No new training started: A model has already been trained on the latest data.'

# %%
# starting training again
ml_repo.run_training()
# Out:
# 'No new training started: A model has already been trained on the latest data.'

# %% [markdown]
# ## Run evaluation
# To measure errors and to provide plots the model must be evaluated on all test and training datasets.

# %%
job_id = ml_repo.run_evaluation()
# print information about the job
info = job_runner.get_info(job_id[0][0], job_id[0][1]) 
print(str(info))
# Out:
# test_user, successfully_finished, started 2019-03-01 17:14:07.884870, finished 2019-03-01 17:14:07.888864

# %% [markdown]
# ## Add and compute measures

# %%
ml_repo.add_measure(MeasureConfiguration.MAX)
ml_repo.add_measure(MeasureConfiguration.R2)
ml_repo.add_measure(MeasureConfiguration.MSE)

# %%
job_ids = ml_repo.run_measures()

# %%
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.load()
print(str(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.obj.value))
# Out:
# 223200.0

# %% [markdown]
# Note that the steps
# - *run_evaluation*
# - *run_measures*
#
# are not necessary if *run_training* is called with the keyword argument *run_descendants=True*.
# In This case the repository would have automatically triggered all evaluations and measurement calculations automatically.

# %% [markdown]
# # Working with the repository
# This section shows how one can work with the audit and revision functionality of the repository.

# %%
from pailab.tools_jupyter import ObjectOverviewList

repo_overview = ObjectOverviewList(ml_repo)
display(repo_overview.get_widget())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# HBox(children=(VBox(children=(SelectMultiple(options=('EVAL_DATA', 'RAW_DATA', 'TRAINING_DATA', 'TEST_DATA', '…

# %%
from pailab.tools_jupyter import ObjectView

obj_view = ObjectView(ml_repo)
display(obj_view.get_widget())
# Out:
# HBox(children=(VBox(children=(SelectMultiple(index=(16,), options=('EVAL_DATA', 'RAW_DATA', 'TRAINING_DATA', '…

# %% [markdown]
# Repository information such as version number, author, date of change are attached to the repo objects and can simply be retrieved:

# %%
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.load()
pprint.pprint(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.obj.repo_info.get_dictionary())
# Out:
# {'author': 'test_user',
#  'big_objects': [],
#  'category': 'MEASURE',
#  'classname': 'pailab.repo_objects.Measure',
#  'commit_date': '2019-03-01 17:14:08.140527',
#  'commit_message': 'computing  measure r2 on data sample1',
#  'description': None,
#  'modification_info': {'DecisionTreeRegressor': '0a66cc7a-3c3d-11e9-8156-fc084a6691eb',
#                        'DecisionTreeRegressor/eval/sample1': '0a88eeb9-3c3d-11e9-830a-fc084a6691eb',
#                        'DecisionTreeRegressor/model': '0a6bacca-3c3d-11e9-8eae-fc084a6691eb',
#                        'DecisionTreeRegressor/model_param': '0a66cc79-3c3d-11e9-a71a-fc084a6691eb',
#                        'sample1': '0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb'},
#  'name': 'DecisionTreeRegressor/measure/sample1/r2',
#  'version': '0aaeb95e-3c3d-11e9-a3bb-fc084a6691eb'}

# %% [markdown]
# The commits can also be queried and printed.

# %%
for k in ml_repo.get_commits():
    pprint.pprint(k.to_dict())
# Out:
# {'author': 'test_user',
#  'message': 'data raw_data/boston_housing added to repository',
#  'objects': {'raw_data/boston_housing': '0a4fa2dc-3c3d-11e9-a3a7-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 517359)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'sample1': '0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 517359)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'sample2': '0a503ed2-3c3d-11e9-acf6-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 521352)}
# {'author': 'test_user',
#  'message': 'add function eval_sklearn of category MODEL_EVAL_FUNCTION to the '
#             'repo',
#  'objects': {'eval_sklearn': '0a663054-3c3d-11e9-8f8f-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 665160)}
# {'author': 'test_user',
#  'message': 'add function train_sklearn of category TRAINING_FUNCTION to the '
#             'repo',
#  'objects': {'train_sklearn': '0a66cc78-3c3d-11e9-9ac4-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 669157)}
# {'author': 'test_user',
#  'message': 'adding model and training parameter',
#  'objects': {'DecisionTreeRegressor/model_param': '0a66cc79-3c3d-11e9-a71a-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 669157)}
# {'author': 'test_user',
#  'message': 'add model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor': '0a66cc7a-3c3d-11e9-8156-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 669157)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/jobs/training': '0a6b10ae-3c3d-11e9-85fe-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 697118)}
# {'author': 'test_user',
#  'message': 'training of model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor/model': '0a6bacca-3c3d-11e9-8eae-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 701114)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample2': '0a87b6be-3c3d-11e9-b6fc-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 884870)}
# {'author': 'test_user',
#  'message': 'evaluate data sample2 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample2': '0a8852c6-3c3d-11e9-9796-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 888864)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample1': '0a88eeb8-3c3d-11e9-bf3e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 892856)}
# {'author': 'test_user',
#  'message': 'evaluate data sample1 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample1': '0a88eeb9-3c3d-11e9-830a-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 896852)}
# {'author': 'test_user',
#  'message': 'added measure max for coordinates all',
#  'objects': {'measure_config': '0a97901a-3c3d-11e9-a836-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 988738)}
# {'author': 'test_user',
#  'message': 'added measure r2 for coordinates all',
#  'objects': {'measure_config': '0a97901b-3c3d-11e9-bce4-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 988738)}
# {'author': 'test_user',
#  'message': 'added measure mse for coordinates all',
#  'objects': {'measure_config': '0a982bda-3c3d-11e9-9df8-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 7, 992725)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/max': '0aab111c-3c3d-11e9-be1d-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 120555)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/max': '0aabad2e-3c3d-11e9-a9b1-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 124549)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/r2': '0aac4936-3c3d-11e9-9ef0-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 124549)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/r2': '0aac4937-3c3d-11e9-8748-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 128543)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/mse': '0aace53a-3c3d-11e9-8acb-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 128543)}
# {'author': 'test_user',
#  'message': 'computing  measure mse on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/mse': '0aad8154-3c3d-11e9-b0fe-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 132539)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/max': '0aad8155-3c3d-11e9-84c9-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 132539)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/max': '0aae1d58-3c3d-11e9-917a-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 136533)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/r2': '0aae1d59-3c3d-11e9-a56a-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 136533)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/r2': '0aaeb95e-3c3d-11e9-a3bb-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 140527)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/mse': '0aaeb95f-3c3d-11e9-82f9-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 144522)}
# {'author': 'test_user',
#  'message': 'computing  measure mse on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/mse': '0aaf5568-3c3d-11e9-810e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 3, 1, 17, 14, 8, 148520)}

# %% [markdown]
# ## Labeling models
# There is the possibility to label a certain version of a model. The label can then be used to access the model instead of the version number. It is vry useful to
# compare e.g. the current productive model (labeld e.g. 'prod') against other model versions. abels are supported by many functions and tools and make life much easier. So the consistency checks only check for the latest and labeled models if there are changes make a rerun of training/evaluation/measures needed. Also som figures will automatically highlight the results belonging to labeled versions.
#
# Let us label the latest model version in the repo.

# %%
ml_repo.tree.models.DecisionTreeRegressor.set_label('prod',version = LAST_VERSION, message='we found our first production model')

# %% [markdown]
# ## Tests
# It is possible to define model tests.
# ### Regressiontests
# Regressiontests compare measuresments on the repositories dataset of a model to th measurements of labeled reference model.

# %%
import pailab.tools.tests
reg_test = pailab.tools.tests.RegressionTestDefinition(reference='prod', models=None, data=None, labels=None, measures=None,  tol=1e-3)

reg_test.repo_info.name='reg_test'
#reg_test.repo_info.category = MLObjectType.TEST_DEFINITION
ml_repo.add(reg_test, message='regression test definition')
#ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.
# Out:
# '0b04ab46-3c3d-11e9-bfd8-fc084a6691eb'

# %%
ml_repo.run_tests()
# Out:
# [('DecisionTreeRegressor/tests/reg_test/sample2',
#   '0b0bfbcc-3c3d-11e9-9712-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '0b0c97e4-3c3d-11e9-9885-fc084a6691eb')]

# %% [markdown]
# ## Consistency checks
# Pailab's *checks*-submodule provides functionality to check for consistency and quality issues as well as for outstanding tasks (such as rerunning a training after the training set has been changed).
#
# ### Model consistency
# There are different checks to test model consistency such as if the tests of a model are up to date and succeeded or if the latest model is trained on the latest trainin data. All model tests are performed for **labeled** models and the latest model only.
# In our first example we change a model parameter but do not train for a new model version wih this parameter.
#
# The following checks are performed:
# - Is the latest model calibrated on the latest parameters and training data
# - Are all labeled models (including latest model) evaluated on the latest available training and test data
# - Are all measures of all labeled models computed on the latest data
# - Have all tests been run on the labeled models

# %%
param = ml_repo.get('DecisionTreeRegressor/model_param')
param.sklearn_params['max_depth'] = 2
version = ml_repo.add(param)
print(param.sklearn_params)
# Out:
# {'criterion': 'mse', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': False, 'random_state': None, 'splitter': 'best'}

# %% [markdown]
# After we have changed the model parameter, we use the *tools* submodules *check_model* method for open tasks/inconsistencies. This method can be called for a certain model or also for a lbeled model. If nothing is specified, all labeled models will be checked.
# Applying the method to the latest model we see that the output shows that the models last version has been calibrated using a different model parameter version then the current version.

# %%
from pailab.tools_jupyter import ConsistencyChecker

consistency_checker = ConsistencyChecker(ml_repo)
display(consistency_checker.get_widget())
# Out:
# VBox(children=(Button(description='update', style=ButtonStyle()), Output()))

# %% [markdown]
# Note that the labeled model would not show an issue. Only the latest model is affected by this change (it is the definition of latest model that it has been calibrated on latest inputs).
#
# We can resolve this issue by simply training the model again (now on the new training data set).

# %%
ml_repo.run_training()
# Out:
# ('DecisionTreeRegressor/jobs/training', '0b293dd4-3c3d-11e9-b30f-fc084a6691eb')

# %% [markdown]
# Note that the solution to simply retrain introduced new issues: The model has not yet been evaluated and no measures have been computed. (If we would have set **run_descendants=False** as argument, the preceding steps would have also been performed and the issues would not have been present).

# %%
ml_repo.run_evaluation(run_descendants=True)# we use run_descendants so that the issues with th measures are resolved too
# Out:
# [('DecisionTreeRegressor/model/jobs/eval_job/sample2',
#   '0b32fe7a-3c3d-11e9-8843-fc084a6691eb'),
#  ('DecisionTreeRegressor/model/jobs/eval_job/sample1',
#   '0b36a746-3c3d-11e9-8a10-fc084a6691eb')]

# %%
ml_repo.run_tests()
# Out:
# [('DecisionTreeRegressor/tests/reg_test/sample2',
#   '0b3f2f5a-3c3d-11e9-ae40-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '0b3fcb62-3c3d-11e9-9ab9-fc084a6691eb')]

# %%
ml_repo.tree.test_data.add('sample3', ml_repo.tree.raw_data.boston_housing(), 0, 50)

# %% [markdown]
# ## Append RawData
# One can append data to the RawData object. The repository manages which objects are affected by appending data and directly updates these objects.

# %%
train_data = ml_repo.get_training_data(full_object = False)
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data) +' Version: '+str(train_data.repo_info.version))
test_data = ml_repo.get_names(MLObjectType.TEST_DATA)
for k in test_data:
    t = ml_repo.get(k)
    print('')
    print(str(k) + ': ' + str(t)+ ' Version: ' + str(t.repo_info.version))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb
#
# sample2: {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 0a503ed2-3c3d-11e9-acf6-fc084a6691eb
#
# sample3: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 0b498c0c-3c3d-11e9-bc20-fc084a6691eb

# %%
from numpy import array
ml_repo.tree.raw_data.boston_housing.append(x_data = array([[ 6.575, 4.98, 15.3]]), y_data =array([[504000.0]]))

# %%
train_data = ml_repo.get_training_data(full_object = False)
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data) +' Version: '+str(train_data.repo_info.version))
test_data = ml_repo.get_names(MLObjectType.TEST_DATA)
for k in test_data:
    t = ml_repo.get(k)
    print('')
    print(str(k) + ': ' + str(t)+ ' Version: ' + str(t.repo_info.version))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb
#
# sample2: {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': '0b5a0126-3c3d-11e9-b484-fc084a6691eb', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb
#
# sample3: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 0b498c0c-3c3d-11e9-bc20-fc084a6691eb

# %% [markdown]
# # Repo-Analysis
# Having parameters, evaluations, measures in one place enables out of the box analysis- and plotting functionality. The submodule *plot* provides automated, standardized plots.

# %%
import pailab.plot as plot

# %% [markdown]
# ## Plotting
# ### Plot errors and measures

# %%
# create more different model params etc. to make the repo more interesting ;-)
for j in range(2):
    training_data = ml_repo.get(ml_repo.tree.training_data.sample1())
    training_data.end_index += 50
    ml_repo.add(training_data, message='add 50 datapoints to end_index')
    for i in range(6,12):
        #print(i)
        param = ml_repo.get(ml_repo.tree.models.DecisionTreeRegressor.model_param())
        param.sklearn_params['max_depth'] = i
        version = ml_repo.add(param)
        ml_repo.add(param)
        ml_repo.run_training()
        ml_repo.run_evaluation()
        ml_repo.run_measures()
        if j == 1 and i==6:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('prod', message='')
        if j == 1 and i==8:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('candidate', message='')

# %% [markdown]
# #### Plot error measure vs parameter

# %%
import pailab.plot_helper as plt_helper
import pailab.plot as plot
plot.measure_by_parameter(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.measures('max'), 'max_depth', data_versions=LAST_VERSION)
ml_repo.tree.models.DecisionTreeRegressor.measures('r2')
# Out:
# <div id="53b338d4-0bcc-4b33-9797-350eca4c9283" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("53b338d4-0bcc-4b33-9797-350eca4c9283", [{"type": "scatter", "x": [6, 5, 7, 8, 9, 10, 11, 6, 7, 8, 9, 10, 11], "y": [400050.0, 387530.76923076925, 336000.0, 342300.0, 342300.0, 342300.0, 342300.0, 407400.0, 310800.0, 407400.0, 310800.0, 407400.0, 407400.0], "text": ["model version: 0b76a71e-3c3d-11e9-875b-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0b74d308-3c3d-11e9-90d9-fc084a6691eb", "model version: 0a6bacca-3c3d-11e9-8eae-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb", "model version: 0b8fa528-3c3d-11e9-b490-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0b74d308-3c3d-11e9-90d9-fc084a6691eb", "model version: 0ba0b60a-3c3d-11e9-8364-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0b74d308-3c3d-11e9-90d9-fc084a6691eb", "model version: 0bb1c728-3c3d-11e9-9668-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0b74d308-3c3d-11e9-90d9-fc084a6691eb", "model version: 0bc2d85c-3c3d-11e9-986c-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0b74d308-3c3d-11e9-90d9-fc084a6691eb", "model version: 0bd3e98a-3c3d-11e9-9ffd-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0b74d308-3c3d-11e9-90d9-fc084a6691eb", "model version: 0be806e6-3c3d-11e9-873a-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0bfb8846-3c3d-11e9-825e-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c0d3594-3c3d-11e9-b620-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c201ad0-3c3d-11e9-956e-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c33001a-3c3d-11e9-bab5-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c42d92c-3c3d-11e9-9b0c-fc084a6691eb<br>sample3: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb"], "name": "DecisionTreeRegressor/measure/sample2/max: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb", "mode": "markers"}, {"type": "scatter", "x": [6, 5, 7, 8, 9, 10, 11], "y": [181860.0, 387530.76923076925, 164710.0, 156800.0, 149940.0, 114660.0, 90037.5], "text": ["model version: 0be806e6-3c3d-11e9-873a-fc084a6691eb<br>sample3: 0be596c8-3c3d-11e9-a805-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0a6bacca-3c3d-11e9-8eae-fc084a6691eb<br>sample3: 0be596c8-3c3d-11e9-a805-fc084a6691eb<br>train_data: 0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb", "model version: 0bfb8846-3c3d-11e9-825e-fc084a6691eb<br>sample3: 0be596c8-3c3d-11e9-a805-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c0d3594-3c3d-11e9-b620-fc084a6691eb<br>sample3: 0be596c8-3c3d-11e9-a805-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c201ad0-3c3d-11e9-956e-fc084a6691eb<br>sample3: 0be596c8-3c3d-11e9-a805-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c33001a-3c3d-11e9-bab5-fc084a6691eb<br>sample3: 0be596c8-3c3d-11e9-a805-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb", "model version: 0c42d92c-3c3d-11e9-9b0c-fc084a6691eb<br>sample3: 0be596c8-3c3d-11e9-a805-fc084a6691eb<br>train_data: 0be596c8-3c3d-11e9-a805-fc084a6691eb"], "name": "DecisionTreeRegressor/measure/sample1/max: 0be596c8-3c3d-11e9-a ...
# ['DecisionTreeRegressor/measure/sample2/r2',
#  'DecisionTreeRegressor/measure/sample1/r2',
#  'DecisionTreeRegressor/measure/sample3/r2']

# %%
#
from pailab.tools_jupyter import Plotter
plotter = Plotter(ml_repo)
display(plotter.get_widget())
# Out:
# VBox(children=(HBox(children=(Button(description='plot', style=ButtonStyle()), SelectMultiple(options=('Decisi…

# %%
ml_repo.get_names(MLObjectType.MODEL_PARAM)
# Out:
# ['DecisionTreeRegressor/model_param']

# %% [markdown]
# #### Plot error vs input variable

# %%
import pailab.plot as plot
plot.scatter_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ['sample1', ml_repo.tree.test_data.sample2()], 'PTRATIO')
# Out:
# <div id="ed294347-436f-4df6-aa53-deba203603dd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ed294347-436f-4df6-aa53-deba203603dd", [{"type": "scatter", "x": [15.3, 15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7, 18.7, 18.7, 18.7, 19.0, 19.0, 19.0, 19.0, 18.5, 18.5, 18.5, 18.5, 17.8, 17.8, 17.8, 17.8, 18.2, 18.2, 18.2, 18.0, 18.0, 18.0, 18.0, 18.0, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.6, 15.6, 12.6, 12.6, 12.6, 17.0, 17.0, 14.7, 14.7, 14.7, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 16.4, 16.4, 16.4, 16.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 16.4, 16.4, 15.9, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 18.6, 18.6, 18.6, 18.6, 18.6, 17.6, 17.6, 17.6, 17.6, 17.6, 14.9, 14.9, 14.9, 14.9, 15.3, 15.3, 18.2, 16.6, 16.6, 16.6, 19.2, 19.2, 19.2, 16.0, 16.0, 16.0, 16.0, 16.0, 14.8, 14.8, 14.8, 16.1, 16.1, 16.1, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2], "y": [4550.0, 4550.0, -42329.4117647059, 7300.0, 29531.25, 38800.0, 106770.5882352941, 21210.0, 150757.89473684208, 0.0, -21442.105263157922, 0.0, -62790.0, 8166.666666666686, -14025.0, -33240.0, -24525.0, 42675.0, -10200.0, 8760.0, -33240.0, 1500.0, -3840.0, -25725.0, 0.0, -17325.0, -13020.0, -29100.0, -34125.0, -51324.0, 3276.0, -17400.0, -110940.0, -6900.0, -29820.0, -600.0, -45525.0, 4560.0, -1425.0, 103260.0, 84656.25, 61031.25, -17100.0, 35370.5882352941, 22770.588235294097, 2775.0, -10140.0, 4560.0, -69742.10526315792, 0.0, -10942.105263157922, -45990.0, -11925.0, 29070.588235294097, 48975.0, 19200.0, 22000.0, 22770.588235294097, -6300.0, -6629.411764705903, -30825.0, -22740.0, 9800.0, -29729.411764705903, 0.0, 21131.25, -2429.411764705903, -52290.0, 19575.0, -50040.0, -3525.0, 12270.588235294097, 40260.0, 36375.0, -4529.411764705903, 10170.588235294097, -46529.4117647059, -17724.0, -924.0, 7476.0, -16125.0, 12300.0, -60243.75, 24870.588235294097, -15029.411764705903, -76440.0, -3543.75, 57060.0, 23775.0, -176268.75, -69168.75, -21329.411764705903, -33929.4117647059, -15029.411764705903, 29070.588235294097, -5124.0, 34256.25, 11676.0, 0.0, 0.0, -24200.0, 1800.0, -19200.0, -47124.0, -32424.0, -15624.0, 64575.0, 64575.0, -9324.0,  ...

# %% [markdown]
# #### Plot histogram of model error

# %%
plot.histogram_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ml_repo.tree.test_data.sample2())
# Out:
# <div id="58d35d7a-b128-4cf6-ba74-5b659be6f896" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("58d35d7a-b128-4cf6-ba74-5b659be6f896", [{"type": "histogram", "x": [21675.0, -8040.0, -42329.4117647059, 350.0, -75240.0, -44542.10526315792, -31733.333333333314, 47376.0, 3276.0, 3870.588235294097, -10829.411764705903, -14025.0, -26940.0, 29070.588235294097, 20670.588235294097, -12929.411764705903, 50760.0, -54390.0, -21329.411764705903, -80129.4117647059, -100590.0, -35025.0, -29729.411764705903, -61229.4117647059, 675.0, -5940.0, -26940.0, -9825.0, -16440.0, -49725.0, -34700.0, -149429.4117647059, -60243.75, -14700.0, -47940.0, -54240.0, -10829.411764705903, -47643.75, -17100.0, -15029.411764705903, 6650.0, -51825.0, -37800.0, -60225.0, -9825.0, 28875.0, 17976.0, 38976.0, 36876.0, 29070.588235294097, -19824.0, 21360.0, 26600.0, 0.0, 44460.0, 69660.0, 74760.0, 74760.0, 0.0, -34650.0, 0.0, 60060.0, -840.0, 0.0, 13860.0, 22260.0, 43260.0, -30240.0, -63840.0, 5460.0, -59640.0, -840.0, 26460.0, 12180.0, 0.0, -11340.0, -36400.0, -78225.0, -69825.0, 47460.0, -36540.0, -110040.0, -82740.0, -97440.0, -63840.0, 39060.0, -40740.0, -36540.0, -110040.0, 34860.0, 170460.0, 146160.0, 57750.0, -100440.0, 34650.0, 160860.0, 127260.0, -68040.0, -63840.0, -121800.0, 3360.0, -30240.0, -343350.0, 24500.0, -28000.0, 21360.0, 66360.0, -59220.0, -40740.0, -112000.0, -97300.0, 15960.0, -15540.0, -40425.0, -223650.0, -99624.0, -44625.0, -80500.0, -45150.0, -143325.0, -32340.0, -38640.0, 53760.0, 5460.0, 144060.0, 41475.0, -163800.0, 11760.0, 32760.0, -32025.0, -80325.0, -48825.0, 57960.0, 2100.0, -25725.0, -6825.0, 58800.0, 33600.0, -48825.0, -220500.0, -61425.0, -32025.0, 93800.0, -525.0, 45500.0, -28224.0, -13524.0, 11676.0, 2460.0, 54075.0, 186060.0, 56175.0, 95900.0, 72975.0, -26124.0, 49476.0, 407400.0, -15120.0, 64260.0, 5775.0, 36960.0, -38325.0, 11676.0, 45276.0, -78000.0, -146868.75, 42360.0, 17160.0, 7476.0, 74900.0, 17160.0, 14280.0, -68040.0, -44940.0, -59325.0, 6660.0, 42360.0, 99060.0, 66757.89473684208, -4642.105263157922, -31140.0, 29760.0, -80033.33333333331, -62640.0, -91743.75, -9825.0, -169968.75], "text": "sample2:last<br>DecisionTreeRegressor/model:0be806e6-3c3d-11e9-873a-fc084a6691eb<br>", "name": "prod, DecisionTreeRegressor/eval/sample2: 0bea771a-3c3d-11e9-abec-fc084a6691eb", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [-17500.0, 17850.0, -19472.727272727294, -3675.0, -49350.0, -31005.882352941204, -6300.0, 21787.5, 7700.0, -6407.692307692312, -21107.692307692312, 3829.411764705903, -40600.0, 18792.307692307688, 10392.307692307688, -23207.692307692312, 37100.0, -37247.36842105264, -31607.692307692312, -57272.727272727294, -83447.36842105264, -17170.588235294097, -40007.69230769231, -71507.69230769231, 18529.411764705903, -19600.0, -40600.0, 8029.411764705903, -30100.0, -31870.588235294097, -38563.63636363635, 0.0, -35910.0, 9975.0, -61600.0, -67900.0, -21107.692307692312, -23310.0, 1050.0, -25307.692307692312, 2625.0, -33970.5882352941, -13125.0, -42370.5882352941, 8029.411764705903, 0.0, 22400.0, 13387.5, 41300.0, 18792.307692307688, -15400.0, 7700.0, 0.0, 0.0, 30800.0, 56000.0, 47600.0, 47600.0, 0.0, 0.0, 0.0, 41475.0, -19425.0, 0.0, -4725.0, 3675.0, 24675.0, 23730.0, -9870.0, 59430.0, -5670.0, 53130.0, 7875.0, -11550.0, 0.0, -29925.0, 0.0, -4200.0, 4200.0, 28875.0, -55125.0, -56070.0, -28770.0, -43470.0, -82425.0, 20475.0, -59325.0, 17430.0, -128625.0, 16275.0, 156800.0, 127575.0, 0.0, -114100.0, 0.0, 0.0, 108675.0, -95200.0, -9870.0, -121800.0, 57330.0, -48825.0, -102900.0, 60900.0, 8400.0, 7700.0, 47775.0, -50400.0, -59325.0, -75600.0, -123900.0, -2625.0, -34125.0, -69300.0, -281400.0, -60900.0, 29400.0, -44100.0, -10500.0, -172200.0, -50925.0, -199500.0, 35175.0, -13125.0, 125475.0, 115500.0, -163800.0, -6825.0, 1 ...

# %% [markdown]
# ### Plot data

# %%
plot.histogram_data(ml_repo, {ml_repo.tree.test_data.sample2() :['last'], ml_repo.tree.training_data.sample1(): ['first','last']}, x_coordinate = 'PTRATIO') #, y_coordinate='MEDV')
# Out:
# <div id="0b27317f-8437-4ed0-ab26-644a00d6a1ee" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0b27317f-8437-4ed0-ab26-644a00d6a1ee", [{"type": "histogram", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0, 21.0], "text": "", "name": "sample2: 0b5a9d38-3c3d-11e9-bb61-fc084a6691eb", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [15.3, 15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7, 18.7, 18.7, 18.7, 19.0, 19.0, 19.0, 19.0, 18.5, 18.5, 18.5, 18.5, 17.8, 17.8, 17.8, 17.8, 18.2, 18.2, 18.2, 18.0, 18.0, 18.0, 18.0, 18.0, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.6, 15.6, 12.6, 12.6, 12.6, 17.0, 17.0, 14.7, 14.7, 14.7, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 16.4, 16.4, 16.4, 16.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 16.4, 16.4, 15.9, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 18.6, 18.6, 18.6, 18.6, 18.6, 17.6, 17.6, 17.6, 17.6, 17.6, 14.9, 14.9, 14.9, 14.9, 15.3, 15.3, 18.2, 16.6, 16.6, 16.6, 19.2, 19.2, 19.2, 16.0, 16.0, 16.0, 16.0, 16.0, 14.8, 14.8, 14.8, 16.1, 16.1, 16.1, 18.4, 18.4, 18.4, 18.4, 18.4], "text": "", "name": "sample1: 0a4fa2dd-3c3d-11e9-9d18-fc084a6691eb", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [15.3, 15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2 ...

# %% [markdown]
# ### Plot projections

# %%
data_1 = ml_repo.get('sample1', full_object = True)
left = data_1.x_data[0,:]
right = data_1.x_data[10,:]
output_index = 0
plot.projection(ml_repo, left = left, right=right, n_steps = 100, output_index = output_index)
# Out:
# <div id="434436c7-1e5f-401a-965f-a5bb0b6f1d60" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("434436c7-1e5f-401a-965f-a5bb0b6f1d60", [{"type": "scatter", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.050505050505050504, 0.06060606060606061, 0.0707070707070707, 0.08080808080808081, 0.09090909090909091, 0.10101010101010101, 0.1111111111111111, 0.12121212121212122, 0.13131313131313133, 0.1414141414141414, 0.15151515151515152, 0.16161616161616163, 0.1717171717171717, 0.18181818181818182, 0.1919191919191919, 0.20202020202020202, 0.21212121212121213, 0.2222222222222222, 0.23232323232323232, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.2727272727272727, 0.2828282828282828, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.3333333333333333, 0.3434343434343434, 0.35353535353535354, 0.36363636363636365, 0.37373737373737376, 0.3838383838383838, 0.3939393939393939, 0.40404040404040403, 0.41414141414141414, 0.42424242424242425, 0.43434343434343436, 0.4444444444444444, 0.45454545454545453, 0.46464646464646464, 0.47474747474747475, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515151, 0.5252525252525253, 0.5353535353535354, 0.5454545454545454, 0.5555555555555556, 0.5656565656565656, 0.5757575757575758, 0.5858585858585859, 0.5959595959595959, 0.6060606060606061, 0.6161616161616161, 0.6262626262626263, 0.6363636363636364, 0.6464646464646465, 0.6565656565656566, 0.6666666666666666, 0.6767676767676768, 0.6868686868686869, 0.696969696969697, 0.7070707070707071, 0.7171717171717171, 0.7272727272727273, 0.7373737373737373, 0.7474747474747475, 0.7575757575757576, 0.7676767676767676, 0.7777777777777778, 0.7878787878787878, 0.797979797979798, 0.8080808080808081, 0.8181818181818182, 0.8282828282828283, 0.8383838383838383, 0.8484848484848485, 0.8585858585858586, 0.8686868686868687, 0.8787878787878788, 0.8888888888888888, 0.898989898989899, 0.9090909090909091, 0.9191919191919192, 0.9292929292929293, 0.9393939393939394, 0.9494949494949495, 0.9595959595959596, 0.9696969696969697, 0.9797979797979798, 0.98989898989899, 1.0], "y": [499450.0, 499450.0, 604100.0, 604100.0, 604100.0, 604100.0, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 495929.4117647059, 578340.0, 578340.0, 578340.0, 578340.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 459690.0, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 447533.3333333333, 418342.1052631579, 418342.1052631579, 418342.1052631579, 418342.1052631579, 418342.1052631579, 418342.1052631579, 418342.1052631579, 418342.1052631579, 418342.1052631579], "name": "prod"}, {"type": "scatter", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.050505050505050504, 0.060606060606 ...

# %%
plot.histogram_data_conditional_error(ml_repo,  ml_repo.tree.models.DecisionTreeRegressor.model(),ml_repo.tree.test_data.sample2(), x_coordinate = 'PTRATIO')
# Out:
# <div id="1a29284e-0db2-4cef-958d-f4e26451fe66" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1a29284e-0db2-4cef-958d-f4e26451fe66", [{"type": "histogram", "x": [20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.9, 20.2, 20.2, 21.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2], "text": "sample2:last<br>DecisionTreeRegressor/model:0be806e6-3c3d-11e9-873a-fc084a6691eb<br>", "name": "prod:0.1", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0], "text": "sample2:last<br>DecisionTreeRegressor/model:0be806e6-3c3d-11e9-873a-fc084a6691eb<br>", "name": "prod", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 21.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2], "text": "sample2:last<br>DecisionTreeRegressor/model:0c0d3594-3c3d-11e9-b620-fc084a6691eb<br>", "name": "candidate:0.1", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0], "text": "sample2:last<br>DecisionTreeRegressor/model:0c0d3594-3c3d-11e9-b620-fc084a6691eb<br>", "name": "candidate", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [20.2, 20.2, 20.2, 20.2, 21.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2], "text": "sample2:last<br>DecisionTreeRegressor/model:0c42d92c-3c3d-11e9-9b0c-fc084a6691eb<br>", "name": "DecisionTreeRegressor/eval/sample2: 0c45e566-3c3d-11e9-ba4f-fc084a6691eb:0.1", "opacity": 0.5, "histnorm": "probability"}, {"type": "histogram", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, ...
