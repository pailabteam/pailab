# %% [markdown]
# # MLRepo - A Quick Introduction using SQLiteJobRunner
# This notebook is very similar to the boston_housing.ipynb notebook with the difference that we use here the asynchronous SQLiteJobRunner.
# As the name indicates the SQLiteJobRunner is a very simple JobRunner using a SQLite DB. So, using a network drive where the MLRepo as well as th JobRunner store all their data it may be possible by running SQLiteJobRunner clients on different machines to seup a distributed computational environmnt: With all advantages and disadvantages using SQLite on a distributed system. This may be e.g. useful if you are in a company where you do not like to involve the IT department but you want to try to use your colleagues machines to e.g. parallelize certain parameterstudies.

# %%
#import all things you need to get startes
import time
import pandas as pd
import logging as logging
import pprint
import plotly
plotly.offline.init_notebook_mode(connected=True)

# Here start the repository specific imports
import pailab.ml_repo.memory_handler as memory_handler
from pailab import RepoInfoKey, MeasureConfiguration, MLRepo, DataSet, MLObjectType, FIRST_VERSION, LAST_VERSION
from pailab.job_runner.job_runner import SimpleJobRunner, JobState, SQLiteJobRunner

#You may set the loglevel and log-format here. 
logging.basicConfig(level=logging.FATAL)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# We define a function to wait for the external JobRunner to be finished. This is mainly used for presentational purposes and is not necessary in real life situations if you are using the respective methods with run_descendants=True.

# %%
def wait_for_waiting_jobs(job_runner):
    ''' Waits until no job is waiting anymore. It is just used for demonstration purposes so that
        the notebook does not lead to errors executing cells although using result from jobs which have no yet been finished.
    '''
    while len(job_runner.get_waiting_jobs()) > 0:
        time.sleep(2)

# %% [markdown]
# # Read the data
# As an example machine learning task to ilustrate the way of working with the repository we use the Boston housing data from the  [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.php) where we have applied some preprocessing. The data consists of house prices together with the house features `'RM'`, `'LSTAT'`, and `'PTRATIO'`:
# - `'RM'` is the average number of rooms among homes in the neighborhood.
# - `'LSTAT'` is the percentage of homeowners in the neighborhood considered "lower class" (working poor).
# - `'PTRATIO'` is the ratio of students to teachers in primary and secondary schools in the neighborhood.
# We just read the csv-file containing the data (also in the repository) into a pandas dataframe.

# %%
data = pd.read_csv('housing.csv')

# %% [markdown]
# # Create a new repository
# In contrast to the [boston_housing](https://nbviewer.jupyter.org/github/pailabteam/pailab/blob/develop/examples/boston_housing/boston_housing.ipynb) notebook we now store all objects on disk (which is a more realistic use case) configuring the respective stores.
# **Please make sure to adjust the directories according to your preferences.**

# %%
# setting up the repository
config = {'user': 'test_user',
      'workspace': 'c:/temp',
      'repo_store': 
      {
          'type': 'disk_handler',  
          'config': {
              'folder': 'c:/temp', 
              'file_format': 'pickle'
          }
      },
      'numpy_store':
      {
          'type': 'hdf_handler',
          'config':{
              'folder': 'c:/temp/hdf',
              'version_files': True
          }
      },
      'job_runner':
      {
          'type': 'sqlite',
          'config': {
              'sqlite_db_name': 'c:/temp/job_runner.sqlite'
          }
      }
    }
ml_repo = MLRepo( user = 'test_user', config=config)
job_runner = ml_repo._job_runner

# %% [markdown]
# # Start a new SQLiteJobRunner Client
# The repo will now execute all jobs (training, evaluation,...) using the SQLJobRunner. For this we need to start at least one client of this job runner. We may do this by simply executing the notebook  [start_job_runner](https://github.com/pailabteam/pailab/blob/develop/examples/start_job_runner.ipynb). **Note that all directory settings must be equal to the settings in this notebook.** If you are using a network drive, you may also start the client in a different machine. If you like, you can also start more then one client.

# %% [markdown]
# # Setup repo

# %% [markdown]
# ## Add a tree
# To navigate in a simple way over all objects, one can add a so-called tree to the repository. The tree allows one to use auto completion to acces objcts and respectiv methods.

# %%
from pailab.tools.tree import MLTree
MLTree.add_tree(ml_repo)

# %% [markdown]
# ## Adding data
# The data in the repository is handled by two different data objects:
# - RawData is the object containing real data.
# - DataSet is the object conaining the logical data, i.e. a reference to a RawData object together with a specification, which data from the RawData will be used. Here, one can specify a fixed version of the underlying RawData object (then changes to the RawData will not affect the derived DataSet) or a fixed or floating subset of the RawData by defininga start and endindex cutting the derived data just out of the original data.
#
# Normally one will add RawData and then define DataSets which are used to train or test a model which is exactly the way shown in the following.

# %%
# Add RawData. A convenient way to add RawData is simply to use the method add on the raw_data collection.
# This method just takes a pandas dataframe and the specification, which columns belong to the input 
#and which to the targets.
ml_repo.tree.raw_data.add('boston_housing', data,  input_variables=['RM', 'LSTAT', 'PTRATIO'], target_variables = ['MEDV'])
# based on the raw data we now define training and test sets
ml_repo.tree.training_data.add('sample1', ml_repo.tree.raw_data.boston_housing(), 0, 300)
ml_repo.tree.test_data.add('sample2', ml_repo.tree.raw_data.boston_housing(), 301, None)

# %%
ml_repo.tree.training_data.sample1.history()
# Out:
# {'19ba488c-67ec-11e9-9e5c-fc084a6691eb': {'RepoInfoKey.AUTHOR': 'test_user',
#   'RepoInfoKey.COMMIT_DATE': '2019-04-26 08:25:35.309223',
#   'RepoInfoKey.COMMIT_MESSAGE': ''}}

# %% [markdown]
# When creating the DataSet we have to set two important informations for the repository, given as a dictionary:
# - The object name. Each object in the repository needs to have a unique name in the repository.
# - The object type which gives. In our example here we say that we specify that the DataSet are training and test data. Note that on can have only one training data object pre repository while the repository can obtain many different test data sets.
#
# Some may wonder what is now stored in *version_list*.
# ** Adding an object (independent if it is a data object or some other object such as a parameter), the object gets a version number and no object will be removed, adding just adds a new version.** The add method returns a dictionary of the object names together with their version number.

# %% [markdown]
# ## Adding a model
# The next step to do machine learning would be to define a model which will be used in the repository. A model consists of the following pieces
# - a skript where the code for the model valuation is defined together with the function name of the evaluation method
# - a skript where the code for the model training is defined together with th function nam of the training method
# - a model parameter object defining the model parameter and which must have implemented the correct interface so that it can be used within the repository (see the documentation on integrating new objects, normally there is not more to do then just simply add *@repo_object_init()* to the line above your *__init__* method)
# - a training parameter object defining training parameters (such as number of optimization steps etc.), if necessary for your algorithms (this oen is optional)
#
# ** SKLearn models as an example**
#
# We do not have to define the pieces defined above, if we use the sklearn module. Instead we can use the pailab.externals.sklearn module interfacing
# the sklearn package so that this can be used within the repository. This interface provides a simple method (add_model) to add an arbitrary sklearn model as a model which can be handled by the repository. This method adds a bunch of repo objects to the repository (according to the pieces described above):
# - An object defining the function to be called to evaluate the model
# - An object defining the function to be called to train the model
# - An object defining the model
# - An object defining the model parameter
# For the following we just use a DecisionTree as our model.

# %%
import pailab.externals.sklearn_interface as sklearn_interface
from sklearn.tree import DecisionTreeRegressor
sklearn_interface.add_model(ml_repo, DecisionTreeRegressor(), model_param={'max_depth': 5})

# %% [markdown]
# ## Train the model
# Now, model taining is very simple, since you have defined training and testing data as well as  methods to value and fit your model and the model parameter.
# So, you can just call *run_training* on the repository, and the training is perfomred automatically.
# The training job is executed via the JobRunner you specified setting up the repository. All method of the repository involving jobs return the job id when adding the job to the JobRunner so that you can control the status of the task and see if it sucessfully finished.
#
# **NOTE This cell will be executed until wait_for_waiting_jobs is completed. This is the case as soon as the JobRunner has finished all scheduled jobs.If you are using runnin a client using [start_job_runner](https://github.com/pailabteam/pailab/blob/develop/examples/start_job_runner.ipynb), execute the last cell with the run command in this notebook.**

# %%
job_id = ml_repo.run_training() 
print(job_id)
job_info = job_runner.get_info(job_id[0], job_id[1])
wait_for_waiting_jobs(job_runner) #wait until all jobs have been finished
# Out:
# ('DecisionTreeRegressor/jobs/training', '1a3bfbe8-67ec-11e9-a111-fc084a6691eb')

# %% [markdown]
# ## Run evaluation
# To measure errors and to provide plots the model must be evaluated on all test and training datasets.

# %%
job_id = ml_repo.run_evaluation()
wait_for_waiting_jobs(job_runner)
# print information about the job
info = job_runner.get_info(job_id[0][0], job_id[0][1]) 
print(str(info))
# Out:
# {'job_name': 'DecisionTreeRegressor/model/jobs/eval_job/sample2', 'job_version': '2060c9da-67ec-11e9-bf1b-fc084a6691eb', 'job_state': 'successfully_finished', 'start_time': '2019-04-26 08:25:47.075035', 'end_time': '2019-04-26 08:25:47.342434', 'error_message': None, 'stack_trace': None, 'insert_time': '2019-04-26 06:25:46', 'unfinished_pred_jobs': 0, 'user': 'test_user'}

# %% [markdown]
# ## Add and compute measures

# %%
ml_repo.add_measure(MeasureConfiguration.MAX)
ml_repo.add_measure(MeasureConfiguration.R2)

# %%
job_ids = ml_repo.run_measures()
wait_for_waiting_jobs(job_runner)

# %%
ml_repo.tree.reload()
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.load()
print(str(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.obj.value))
# Out:
# 223200.0

# %% [markdown]
# Note that the steps
# - *run_evaluation*
# - *run_measures*
#
# are not necessary if *run_training* is called with the keyword argument *run_descendants=True*.
# In this case all evaluations and measurement calculations are triggered automatically.

# %% [markdown]
# # Working with the repository
# This section shows how one can work with the audit and revision functionality of the repository.

# %%
for k in MLObjectType:
    names = ml_repo.get_names(k.value)
    for n in names: 
        print(n + '\t  ' + k.value)
# Out:
# raw_data/boston_housing	  RAW_DATA
# DecisionTreeRegressor/eval/sample2	  RAW_DATA
# DecisionTreeRegressor/eval/sample1	  RAW_DATA
# sample1	  TRAINING_DATA
# sample2	  TEST_DATA
# DecisionTreeRegressor/model_param	  MODEL_PARAM
# train_sklearn	  TRAINING_FUNCTION
# eval_sklearn	  MODEL_EVAL_FUNCTION
# DecisionTreeRegressor	  MODEL
# DecisionTreeRegressor/model	  CALIBRATED_MODEL
# CommitInfo	  COMMIT_INFO
# repo_mapping	  MAPPING
# DecisionTreeRegressor/measure/sample2/max	  MEASURE
# DecisionTreeRegressor/measure/sample1/max	  MEASURE
# DecisionTreeRegressor/measure/sample1/r2	  MEASURE
# DecisionTreeRegressor/measure/sample2/r2	  MEASURE
# measure_config	  MEASURE_CONFIGURATION
# DecisionTreeRegressor/jobs/training	  JOB
# DecisionTreeRegressor/model/jobs/eval_job/sample2	  JOB
# DecisionTreeRegressor/model/jobs/eval_job/sample1	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample2/max	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample2/r2	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample1/max	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample1/r2	  JOB

# %% [markdown]
# Repository information such as version number, author, date of change are attached to the repo objects and can simply be retrieved:

# %%
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.load()
pprint.pprint(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.obj.repo_info.get_dictionary())
# Out:
# {'author': 'test_user',
#  'big_objects': [],
#  'category': 'MEASURE',
#  'classname': 'pailab.ml_repo.repo_objects.Measure',
#  'commit_date': '2019-04-26 08:25:50.558002',
#  'commit_message': 'computing  measure r2 on data sample1',
#  'description': None,
#  'modification_info': {'DecisionTreeRegressor': '1a262be2-67ec-11e9-92df-fc084a6691eb',
#                        'DecisionTreeRegressor/eval/sample1': '20fbd7ec-67ec-11e9-aee2-fc084a6691eb',
#                        'DecisionTreeRegressor/model': '20037f92-67ec-11e9-888f-fc084a6691eb',
#                        'DecisionTreeRegressor/model_param': '1a13e29e-67ec-11e9-ad56-fc084a6691eb',
#                        'sample1': '19ba488c-67ec-11e9-9e5c-fc084a6691eb'},
#  'name': 'DecisionTreeRegressor/measure/sample1/r2',
#  'version': '22d10ffe-67ec-11e9-85d5-fc084a6691eb'}

# %% [markdown]
# The commits can also be queried and printed.

# %%
for k in ml_repo.get_commits():
    pprint.pprint(k.to_dict())
# Out:
# {'author': 'test_user',
#  'message': 'data raw_data/boston_housing added to repository',
#  'objects': {'raw_data/boston_housing': '19a02f10-67ec-11e9-a8af-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 35, 249299)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'sample1': '19ba488c-67ec-11e9-9e5c-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 35, 369140)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'sample2': '19cc925c-67ec-11e9-8c28-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 35, 493006)}
# {'author': 'test_user',
#  'message': 'add function eval_sklearn of category MODEL_EVAL_FUNCTION to the '
#             'repo',
#  'objects': {'eval_sklearn': '19eb0bc2-67ec-11e9-9f8e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 35, 720670)}
# {'author': 'test_user',
#  'message': 'add function train_sklearn of category TRAINING_FUNCTION to the '
#             'repo',
#  'objects': {'train_sklearn': '1a023552-67ec-11e9-b849-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 35, 840513)}
# {'author': 'test_user',
#  'message': 'adding model and training parameter',
#  'objects': {'DecisionTreeRegressor/model_param': '1a13e29e-67ec-11e9-ad56-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 35, 960351)}
# {'author': 'test_user',
#  'message': 'add model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor': '1a262be2-67ec-11e9-92df-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 36, 76204)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/jobs/training': '1a3bfbe8-67ec-11e9-a111-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 36, 260182)}
# {'author': 'test_user',
#  'message': 'training of model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor/model': '20037f92-67ec-11e9-888f-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 45, 912527)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample2': '2060c9da-67ec-11e9-bf1b-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 46, 554167)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample1': '207ed13e-67ec-11e9-8b35-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 46, 743450)}
# {'author': 'test_user',
#  'message': 'evaluate data sample2 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample2': '20c7af58-67ec-11e9-a1ca-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 47, 232195)}
# {'author': 'test_user',
#  'message': 'evaluate data sample1 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample1': '20fbd7ec-67ec-11e9-aee2-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 47, 598774)}
# {'author': 'test_user',
#  'message': 'added measure max for coordinates all',
#  'objects': {'measure_config': '21cf1dba-67ec-11e9-af59-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 48, 971876)}
# {'author': 'test_user',
#  'message': 'added measure r2 for coordinates all',
#  'objects': {'measure_config': '21e6618c-67ec-11e9-9aad-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 49, 86888)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/max': '21fadddc-67ec-11e9-bff4-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 49, 257983)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/r2': '22190588-67ec-11e9-9b09-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 49, 423538)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/max': '2234a466-67ec-11e9-a394-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 49, 595374)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/r2': '22514592-67ec-11e9-ad56-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 49, 783795)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/max': '22693ad2-67ec-11e9-ae0e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 49, 971253)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/max': '22a00d9e-67ec-11e9-86eb-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 50, 299303)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/r2': '22d10ffe-67ec-11e9-85d5-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 50, 636109)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/r2': '23483e66-67ec-11e9-aef5-fc084a6691eb'},
#  'time': datetime.datetime(2019, 4, 26, 8, 25, 51, 417178)}

# %% [markdown]
# ## Labeling models
# There is the possibility to label a certain version of a model. The label can then be used to access the model instead of the version number. It is vry useful to
# compare e.g. the current productive model (labeld e.g. 'prod') against other model versions. abels are supported by many functions and tools and make life much easier. So the consistency checks only check for the latest and labeled models if there are changes make a rerun of training/evaluation/measures needed. Also som figures will automatically highlight the results belonging to labeled versions.
#
# Let us label the latest model version in the repo.

# %%
ml_repo.tree.models.DecisionTreeRegressor.set_label('prod',version = LAST_VERSION, message='we found our first production model')

# %% [markdown]
# ## Tests
# It is possible to define model tests.
# ### Regressiontests
# Regressiontests compare measuresments on the repositories dataset of a model to th measurements of labeled reference model.

# %%
import pailab.tools.tests
reg_test = pailab.tools.tests.RegressionTestDefinition(reference='prod', models=None, data=None, labels=None, measures=None,  tol=1e-3)
reg_test.repo_info.name='reg_test'
#reg_test.repo_info.category = MLObjectType.TEST_DEFINITION
ml_repo.add(reg_test, message='regression test definition')
#ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.
# Out:
# '23e44750-67ec-11e9-aa9f-fc084a6691eb'

# %%
ml_repo.run_tests()
# Out:
# [('DecisionTreeRegressor/tests/reg_test/sample2',
#   '24018338-67ec-11e9-9a1e-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '241e7594-67ec-11e9-b4bb-fc084a6691eb')]

# %% [markdown]
# ## Consistency checks
# Pailab's *checks*-submodule provides functionality to check for consistency and quality issues as well as for outstanding tasks (such as rerunning a training after the training set has been changed).
#
# ### Model consistency
# There are different checks to test model consistency such as if the tests of a model are up to date and succeeded or if the latest model is trained on the latest trainin data. All model tests are performed for **labeled** models and the latest model only.
# In our first example we change a model parameter but do not train for a new model version wih this parameter.
#
# The following checks are performed:
# - Is the latest model calibrated on the latest parameters and training data
# - Are all labeled models (including latest model) evaluated on the latest available training and test data
# - Are all measures of all labeled models computed on the latest data
# - Have all tests been run on the labeled models

# %%
param = ml_repo.get('DecisionTreeRegressor/model_param')
param.sklearn_params['max_depth'] = 2
version = ml_repo.add(param)
print(param.sklearn_params)
# Out:
# {'criterion': 'mse', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': False, 'random_state': None, 'splitter': 'best'}

# %% [markdown]
# After we have changed the model parameter, we use the *tools* submodules *check_model* method for open tasks/inconsistencies. This method can be called for a certain model or also for a lbeled model. If nothing is specified, all labeled models will be checked.
# Applying the method to the latest model we see that the output shows that the models last version has been calibrated using a different model parameter version then the current version.

# %%
import pailab.tools.checker as checker
results = checker.run(ml_repo)
pprint.pprint(results)
# Out:
# [{'DecisionTreeRegressor/model:last': {'latest model version not on latest inputs': {'DecisionTreeRegressor/model_param': {'latest version': '244a3cec-67ec-11e9-bc5c-fc084a6691eb',
#                                                                                                                            'modifier version': '1a13e29e-67ec-11e9-ad56-fc084a6691eb'}}}}]

# %% [markdown]
# Note that the labeled model would not show an issue. Only the latest model is affected by this change (it is the definition of latest model that it has been calibrated on latest inputs).
#
# We can resolve this issue by simply training the model again (now on the new training data set).

# %%
ml_repo.run_training()
wait_for_waiting_jobs(job_runner)

# %% [markdown]
# Note that the solution to simply retrain introduced new issues: The model has not yet been evaluated and no measures have been computed. (If we would have set **run_descendants=False** as argument, the preceding steps would have also been performed and the issues would not have been present).

# %%
results = checker.run(ml_repo)
pprint.pprint(results)
# Out:
# [{'DecisionTreeRegressor/model:last': {'evaluations missing': {'sample1': '19ba488c-67ec-11e9-9e5c-fc084a6691eb',
#                                                                'sample2': '19cc925c-67ec-11e9-8c28-fc084a6691eb'},
#                                        'measures not calculated': {'DecisionTreeRegressor/measure/sample1/max',
#                                                                    'DecisionTreeRegressor/measure/sample1/r2',
#                                                                    'DecisionTreeRegressor/measure/sample2/max',
#                                                                    'DecisionTreeRegressor/measure/sample2/r2'}}}]

# %%
ml_repo.run_evaluation(run_descendants=True)# we use run_descendants so that the issues with th measures are resolved too
wait_for_waiting_jobs(job_runner)

# %%
results = checker.run(ml_repo)
pprint.pprint(results)
# Out:
# []

# %% [markdown]
# ### Checking training and test data consistency
# There may be also data inconsistencies, so for example the training and test data overlap. The **check_data** methods performs such a test.
#
# Let us first add a new test data set which overlaps with the training data

# %%
ml_repo.tree.test_data.add('sample3', ml_repo.tree.raw_data.boston_housing(), 0, 50)

# %%
checker.run(ml_repo)
# Out:
# [{'DecisionTreeRegressor/model:last': {'evaluations missing': {'sample3': '284cebb8-67ec-11e9-8617-fc084a6691eb'},
#    'measures not calculated': {'DecisionTreeRegressor/measure/sample3/max',
#     'DecisionTreeRegressor/measure/sample3/r2'}}},
#  {'prod': {'evaluations missing': {'sample3': '284cebb8-67ec-11e9-8617-fc084a6691eb'},
#    'measures not calculated': {'DecisionTreeRegressor/measure/sample3/max',
#     'DecisionTreeRegressor/measure/sample3/r2'}}},
#  {'sample3': {'training and test data overlap': {'sample1': '19ba488c-67ec-11e9-9e5c-fc084a6691eb',
#     'sample3': '284cebb8-67ec-11e9-8617-fc084a6691eb'}}}]

# %% [markdown]
# ### Checking usage of RawData
# The check_data method includes also a check if all RawData is used in DataSets or if there is some unused data.

# %% [markdown]
# ### Checking test status
# There is also a check if all latest tests have been applied to all labeled models and all latest models.

# %%
checker.Tests.run(ml_repo)
#depp = ml_repo.get('DecisionTreeRegressor/tests/reg_test/sample1')
#depp.repo_info.commit_date
# Out:
# {'DecisionTreeRegressor/model:24b7c476-67ec-11e9-a13c-fc084a6691eb': {'DecisionTreeRegressor/tests/reg_test/sample1': 'Test for model DecisionTreeRegressor/model, version 24b7c476-67ec-11e9-a13c-fc084a6691eb on latest data sample1 missing.',
#   'DecisionTreeRegressor/tests/reg_test/sample2': 'Test for model DecisionTreeRegressor/model, version 24b7c476-67ec-11e9-a13c-fc084a6691eb on latest data sample2 missing.',
#   'DecisionTreeRegressor/tests/reg_test/sample3': 'Test for model DecisionTreeRegressor/model, version 24b7c476-67ec-11e9-a13c-fc084a6691eb on latest data sample3 missing.'},
#  'DecisionTreeRegressor/model:prod': {'DecisionTreeRegressor/tests/reg_test/sample1': "Test for model DecisionTreeRegressor/model, version 20037f92-67ec-11e9-888f-fc084a6691eb on latest data sample1 failed, details: {'max': {'reference_value': 223200.0, 'value': 223200.0}, 'r2': {'reference_value': 0.92140837838916367, 'value': 0.92140837838916367}}",
#   'DecisionTreeRegressor/tests/reg_test/sample2': "Test for model DecisionTreeRegressor/model, version 20037f92-67ec-11e9-888f-fc084a6691eb on latest data sample2 failed, details: {'max': {'reference_value': 415450.0, 'value': 415450.0}, 'r2': {'reference_value': -0.39357478010295743, 'value': -0.39357478010295743}}",
#   'DecisionTreeRegressor/tests/reg_test/sample3': 'Test for model DecisionTreeRegressor/model, version 20037f92-67ec-11e9-888f-fc084a6691eb on latest data sample3 missing.'}}

# %%
ml_repo.run_evaluation()
wait_for_waiting_jobs(job_runner)
ml_repo.run_measures()
wait_for_waiting_jobs(job_runner)
ml_repo.run_tests()
pprint.pprint(checker.Tests.run(ml_repo))
#ml_repo.tree.models.DecisionTreeRegressor.tests.reg_test.sample3.obj.state
# Out:
# {'DecisionTreeRegressor/model:24b7c476-67ec-11e9-a13c-fc084a6691eb': {'DecisionTreeRegressor/tests/reg_test/sample1': 'Test '
#                                                                                                                       'for '
#                                                                                                                       'model '
#                                                                                                                       'DecisionTreeRegressor/model, '
#                                                                                                                       'version '
#                                                                                                                       '24b7c476-67ec-11e9-a13c-fc084a6691eb '
#                                                                                                                       'on '
#                                                                                                                       'latest '
#                                                                                                                       'data '
#                                                                                                                       'sample1 '
#                                                                                                                       'failed, '
#                                                                                                                       'details: '
#                                                                                                                       "{'r2': "
#                                                                                                                       "{'reference_value': "
#                                                                                                                       '0.92140837838916367, '
#                                                                                                                       "'value': "
#                                                                                                                       '0.79975324932539471}}',
#                                                                       'DecisionTreeRegressor/tests/reg_test/sample2': 'Test '
#                                                                                                                       'for '
#                                                                                                                       'model '
#                                                                                                                       'DecisionTreeRegressor/model, '
#                                                                                                                       'version '
#                                                                                                                       '24b7c476-67ec-11e9-a13c-fc084a6691eb '
#                                                                                                                       'on '
#                                                                                                                       'latest '
#                                                                                                                       'data '
#                                                                                                                       'sample2 '
#                                                                                                                       'failed, '
#                                                                                                                       'details: '
#                                                                                                                       "{'r2': "
#                                                                                                                       "{'reference_value': "
#                                                                                                                       '-0.39357478010295743, '
#                                                                                                                       "'value': "
#                                                                                                                       '-0.56036457019792563}}',
#                                                                       'DecisionTreeRegressor/tests/reg_test/sample3': 'Test '
#                                                                                                                       'for '
#                                                                                                                       'model '
#                                                                                                                       'DecisionTreeRegressor/model, '
#                                                                                                                       'version '
#                                                                                                                       '24b7c476-67ec-11e9-a13c-fc084a6691eb '
#                                                                                                                       'on '
#                                                                                                                       'latest '
#                                                                                                                       'data '
#                                                                                                                       'sample3 '
#                                                                                                                       'failed, '
#                                                                                                                       'details: '
#                                                                                                                       "{'r2': "
#                                                                                                                       "{'reference_value': "
#                                                                                                                       '0.84412474735986232, '
#                                                                                                                       "'value': "
#                                                                                                                       '0.6284766710609937}}'},
#  'DecisionTreeRegressor/model:prod': {'DecisionTreeRegressor/tests/reg_test/sample1': 'Test '
#                                                                                       'for '
#                                                                                       'model '
#                                                                                       'DecisionTreeRegressor/model, '
#                                                                                       'version '
#                                                                                       '20037f92-67ec-11e9-888f-fc084a6691eb '
#                                                                                       'on '
#                                                                                       'latest '
#                                                                                       'data '
#                                                                                       'sample1 '
#                                                                                       'failed, '
#                                                                                       'details: '
#                                                                                       "{'max': "
#                                                                                       "{'reference_value': "
#                                                                                       '223200.0, '
#                                                                                       "'value': "
#                                                                                       '223200.0}, '
#                                                                                       "'r2': "
#                                                                                       "{'reference_value': "
#                                                                                       '0.92140837838916367, '
#                                                                                       "'value': "
#                                                                                       '0.92140837838916367}}',
#                                       'DecisionTreeRegressor/tests/reg_test/sample2': 'Test '
#                                                                                       'for '
#                                                                                       'model '
#                                                                                       'DecisionTreeRegressor/model, '
#                                                                                       'version '
#                                                                                       '20037f92-67ec-11e9-888f-fc084a6691eb '
#                                                                                       'on '
#                                                                                       'latest '
#                                                                                       'data '
#                                                                                       'sample2 '
#                                                                                       'failed, '
#                                                                                       'details: '
#                                                                                       "{'max': "
#                                                                                       "{'reference_value': "
#                                                                                       '415450.0, '
#                                                                                       "'value': "
#                                                                                       '415450.0}, '
#                                                                                       "'r2': "
#                                                                                       "{'reference_value': "
#                                                                                       '-0.39357478010295743, '
#                                                                                       "'value': "
#                                                                                       '-0.39357478010295743}}',
#                                       'DecisionTreeRegressor/tests/reg_test/sample3': 'Test '
#                                                                                       'for '
#                                                                                       'model '
#                                                                                       'DecisionTreeRegressor/model, '
#                                                                                       'version '
#                                                                                       '20037f92-67ec-11e9-888f-fc084a6691eb '
#                                                                                       'on '
#                                                                                       'latest '
#                                                                                       'data '
#                                                                                       'sample3 '
#                                                                                       'missing.'}}

# %% [markdown]
# ## Easy access to repo objects and names
# Since the names are chosen equally to a directory structure (with subdirectories) they may be long and difficult to remember (especially the order). And even if one remembers the long names, it is a lot of work to type them.

# %% [markdown]
# If you now type the objects name followd by a '.' by pressing tab you will see the possible next solutions makin it very easy to 'browse' to the object's name you have in mind. By using '()' operator you get a list of names below th current naming level, and in addition you can filter the names by giving a string: Only names containing this string are put into the list.

# %%
ml_repo.tree.models.DecisionTreeRegressor.model_param.load()

# %%
ml_repo.tree.models.DecisionTreeRegressor.model_param.obj.repo_info.get_dictionary()
# Out:
# {'author': 'test_user',
#  'big_objects': [],
#  'category': 'MODEL_PARAM',
#  'classname': 'pailab.externals.sklearn_interface.SKLearnModelParam',
#  'commit_date': '2019-04-26 08:25:53.029860',
#  'commit_message': '',
#  'description': None,
#  'modification_info': {},
#  'name': 'DecisionTreeRegressor/model_param',
#  'version': '244a3cec-67ec-11e9-bc5c-fc084a6691eb'}

# %% [markdown]
# ## Append RawData
# One can append data to the RawData object. The repository manages which objects are affected by appending data and directly updates these objects.

# %%
train_data = ml_repo.get_training_data(full_object = False)
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data))
test_data = ml_repo.get_names(MLObjectType.TEST_DATA)
for k in test_data:
    t = ml_repo.get(k)
    print(str(t)+ ' Version: ' + str(t.repo_info[RepoInfoKey.VERSION]))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489}
# {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 19cc925c-67ec-11e9-8c28-fc084a6691eb
# {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 284cebb8-67ec-11e9-8617-fc084a6691eb

# %%
from numpy import array
ml_repo.tree.raw_data.boston_housing.append(x_data = array([[ 6.575, 4.98, 15.3]]), y_data =array([[504000.0]]))

# %%
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data))
for k in test_data:
    t = ml_repo.get(k)
    print(str(t) + ' Version: ' + str(t.repo_info[RepoInfoKey.VERSION]))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489}
# {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': '2c6adb30-67ec-11e9-84b1-fc084a6691eb', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb
# {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 284cebb8-67ec-11e9-8617-fc084a6691eb

# %%
results = checker.run(ml_repo)
print(results)
# Out:
# [{'DecisionTreeRegressor/model:last': {'evaluations missing': {'sample2': '2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb'}}}, {'prod': {'evaluations missing': {'sample2': '2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb'}}}, {'sample3': {'training and test data overlap': {'sample3': '284cebb8-67ec-11e9-8617-fc084a6691eb', 'sample1': '19ba488c-67ec-11e9-9e5c-fc084a6691eb'}}}]

# %% [markdown]
# # Repo-Analysis
# Having parameters, evaluations, measures in one place enables out of the box analysis- and plotting functionality. The submodule *plot* provides automated, standardized plots.

# %%
import pailab.analysis.plot as plot
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ## Plotting
# ### Plot errors and measures

# %%
# create more different model params etc. to make the repo more interesting ;-)
for j in range(2):
    training_data = ml_repo.get(ml_repo.tree.training_data.sample1())
    training_data.end_index += 50
    ml_repo.add(training_data, message='add 50 datapoints to end_index')
    for i in range(6,12):
        #print(i)
        param = ml_repo.get(ml_repo.tree.models.DecisionTreeRegressor.model_param())
        param.sklearn_params['max_depth'] = i
        version = ml_repo.add(param)
        ml_repo.add(param)
        ml_repo.run_training(run_descendants = True)
        if j == 1 and i==6:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('prod', message='')
        if j == 1 and i==8:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('candidate', message='')

# %% [markdown]
# #### Plot error measure vs parameter

# %%
import pailab.analysis.plot_helper as plt_helper
import pailab.analysis.plot as plot
plot.measure_by_parameter(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.measures('max'), 'max_depth', data_versions=LAST_VERSION)
#ml_repo.models.DecisionTreeRegressor.measures('r2')
# Out:
# <div id="fa4eafb0-cc6c-4a43-ab60-bcd9e405b282" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("fa4eafb0-cc6c-4a43-ab60-bcd9e405b282")) {
#     Plotly.newPlot("fa4eafb0-cc6c-4a43-ab60-bcd9e405b282", [{"mode": "markers", "name": "DecisionTreeRegressor/measure/sample2/max: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb", "text": ["model version: 2e1ccdc8-67ec-11e9-a352-fc084a6691eb<br>sample3: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb<br>train_data: 2cc29386-67ec-11e9-9717-fc084a6691eb", "model version: 30ab14c0-67ec-11e9-88db-fc084a6691eb<br>sample3: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb<br>train_data: 2cc29386-67ec-11e9-9717-fc084a6691eb", "model version: 3645f7da-67ec-11e9-823c-fc084a6691eb<br>sample3: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb<br>train_data: 2cc29386-67ec-11e9-9717-fc084a6691eb", "model version: 336ccccc-67ec-11e9-80c8-fc084a6691eb<br>sample3: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb<br>train_data: 2cc29386-67ec-11e9-9717-fc084a6691eb", "model version: 39d9796e-67ec-11e9-b16a-fc084a6691eb<br>sample3: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb<br>train_data: 398d0146-67ec-11e9-909b-fc084a6691eb", "model version: 3c9c3e30-67ec-11e9-aaa0-fc084a6691eb<br>sample3: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb<br>train_data: 398d0146-67ec-11e9-909b-fc084a6691eb", "model version: 3f04db4a-67ec-11e9-b85d-fc084a6691eb<br>sample3: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb<br>train_data: 398d0146-67ec-11e9-909b-fc084a6691eb"], "x": [7, 8, 11, 9, 6, 8, 9], "y": [342300.0, 336000.0, 342300.0, 336000.0, 401100.0, 407400.0, 407400.0], "type": "scatter", "uid": "f05b6ca1-7c55-49f2-b84a-37ffbb696308"}, {"mode": "markers", "name": "DecisionTreeRegressor/measure/sample1/max: 398d0146-67ec-11e9-909b-fc084a6691eb", "text": ["model version: 39d9796e-67ec-11e9-b16a-fc084a6691eb<br>sample3: 398d0146-67ec-11e9-909b-fc084a6691eb<br>train_data: 398d0146-67ec-11e9-909b-fc084a6691eb", "model version: 3f04db4a-67ec-11e9-b85d-fc084a6691eb<br>sample3: 398d0146-67ec-11e9-909b-fc084a6691eb<br>train_data: 398d0146-67ec-11e9-909b-fc084a6691eb"], "x": [6, 9], "y": [182100.0, 165900.0], "type": "scatter", "uid": "7838720b-71fa-429c-b154-ef20a1e480bb"}, {"mode": "markers", "name": "DecisionTreeRegressor/measure/sample3/max: 284cebb8-67ec-11e9-8617-fc084a6691eb", "text": ["model version: 20037f92-67ec-11e9-888f-fc084a6691eb<br>sample3: 284cebb8-67ec-11e9-8617-fc084a6691eb<br>train_data: 19ba488c-67ec-11e9-9e5c-fc084a6691eb", "model version: 24b7c476-67ec-11e9-a13c-fc084a6691eb<br>sample3: 284cebb8-67ec-11e9-8617-fc084a6691eb<br>train_data: 19ba488c-67ec-11e9-9e5c-fc084a6691eb", "model version: 30ab14c0-67ec-11e9-88db-fc084a6691eb<br>sample3: 284cebb8-67ec-11e9-8617-fc084a6691eb<br>train_data: 2cc29386-67ec-11e9-9717-fc084a6691eb", "model version: 3645f7da-67ec-11e9-823c-fc084a6691eb<br>sample3: 284cebb8-67ec-11e9-8617-fc084a6691eb<br>train_data: 2cc29386-67ec-11e9-9717-fc084a6691eb", "model version: 3c9c3e30-67ec-11e9-aaa0-fc084a6691eb<br>sample3: 284cebb8-67ec-11e9-8617-fc084a6691eb<br>train_data: 398d0146-67ec-11e9-909b-fc084a6691eb", "model version: 430e0d06-67ec-11e9-b914-fc084a6691eb<br>sample3: 284cebb8-67ec-11e9-8617-fc084a6691eb<br>train_data: 398d0146-67ec-11e9-909b-fc084a6691eb"], "x": [5, 2, 8, 11, 8, 11], "y": [162247.82608695654, 169680.0, 91190.90909090912, 90872.7272727273, 113531.25, 88473.91304347827], "type": "scatter", "uid": "09a5c19e-248c-4dfc-86ec-cce7ff8b27da"}], {"annotations": [{"arrowhead": 2, "showarrow": true, "text": "prod", "x": 6, "xref": "x", "y": 401100.0, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "candidate", "x": 8, "xref": "x", "y": 407400.0, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "prod", "x": 6, "xref": "x", "y": 182100.0, "yref": "y"}, {"arrowhead": 2, "showarrow": true, "text": "candidate", "x": 8, "xref": "x", "y": 113531.25, "yref": "y"}], "title": {"text": "measure by parameter"}, "xaxis": {"title": {"text": "max_depth"}}, "yaxis": {"title": {"text": "max"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("fa4eafb0-cc6c-4a43-ab60-bcd9e405b282")) {window._Plotly.Plots.resize(document.getElementById("fa4eafb0-cc6c-4a43-ab60-bcd9e405b282"));};})</script>

# %% [markdown]
# #### Plot error vs input variable

# %%
plot.scatter_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ml_repo.tree.test_data.sample2(), 'PTRATIO')
# Out:
# <div id="f3eb2b64-15d7-4d00-9f95-279094f84bf1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f3eb2b64-15d7-4d00-9f95-279094f84bf1")) {
#     Plotly.newPlot("f3eb2b64-15d7-4d00-9f95-279094f84bf1", [{"mode": "markers", "name": "prod, DecisionTreeRegressor/eval/sample2: 3a8adddc-67ec-11e9-bc25-fc084a6691eb", "text": "sample2:last<br>DecisionTreeRegressor/model:39d9796e-67ec-11e9-b16a-fc084a6691eb<br>", "x": [18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 16.899999618530273, 16.899999618530273, 16.899999618530273, 16.899999618530273, 16.899999618530273, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 15.5, 15.899999618530273, 17.600000381469727, 17.600000381469727, 18.799999237060547, 18.799999237060547, 17.899999618530273, 17.0, 19.700000762939453, 19.700000762939453, 18.299999237060547, 18.299999237060547, 17.0, 22.0, 22.0, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.100000381469727, 20.100000381469727, 20.100000381469727, 20.100000381469727, 20.100000381469727, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 21.0, 21.0, 21.0, 21.0], "y": [-36945.76271186443, -42329.4117647059, -8400.0, -104145.76271186443, -44542.10526315792, -28545.76271186443 ...

# %% [markdown]
# #### Plot histogram of model error

# %%
plot.histogram_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ml_repo.tree.test_data.sample2())
# Out:
# <div id="91d35878-7084-485c-886b-45637b26c7cc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("91d35878-7084-485c-886b-45637b26c7cc")) {
#     Plotly.newPlot("91d35878-7084-485c-886b-45637b26c7cc", [{"histnorm": "percent", "name": "prod, DecisionTreeRegressor/eval/sample2: 3a8adddc-67ec-11e9-bc25-fc084a6691eb", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:39d9796e-67ec-11e9-b16a-fc084a6691eb<br>", "x": [-36945.76271186443, -42329.4117647059, -8400.0, -104145.76271186443, -44542.10526315792, -28545.76271186443, 40754.23728813557, -3345.7627118644305, 3870.588235294097, -10829.411764705903, -15711.111111111124, -31807.317073170736, 29070.588235294097, 20670.588235294097, -12929.411764705903, 45892.682926829264, -39045.76271186443, -21329.411764705903, -80129.4117647059, -85245.76271186443, -36711.111111111124, -29729.411764705903, -61229.4117647059, -1011.111111111124, -10807.317073170736, -31807.317073170736, -11511.111111111124, -21307.317073170736, -51411.111111111124, -14700.0, -149429.4117647059, -61110.0, -1050.0, -52807.317073170736, -59107.317073170736, -10829.411764705903, -50238.4615384615, 28875.0, -15029.411764705903, -58638.4615384615, -53511.111111111124, 10500.0, -61911.111111111124, -11511.111111111124, 28875.0, 35392.682926829264, 56392.682926829264, 54292.682926829264, 29070.588235294097, -2407.317073170736, 16492.682926829264, -17372.727272727294, 0.0, 39592.682926829264, 64792.682926829264, 96000.0, 96000.0, 0.0, 50505.0, 37905.0, 33705.0, -27195.0, 0.0, -12495.0, -4095.0, 16905.0, -9000.0, -42600.0, 26700.0, -38400.0, 20400.0, 105.0, 12180.0, 0.0, -37695.0, -80372.7272727273, -78225.0, -69825.0, 21105.0, -62895.0, -88800.0, -61500.0, -76200.0, -90195.0, 12705.0, -67095.0, -15300.0, -136395.0, 8505.0, 165592.68292682926, 119805.0, 0.0, -105307.31707317074, 119805.0, 182100.0, 100905.0, -46800.0, -42600.0, -83895.0, 24600.0, -56595.0, -401100.0, -19472.727272727294, -71972.7272727273, 16492.682926829264, 40005.0, -59220.0, -67095.0, -155972.7272727273, -141272.7272727273, -10395.0, -41895.0, -40425.0, -281400.0, -82207.31707317074, -44625.0, -124472.7272727273, 40005.0, -143325.0, -58695.0, -17400.0, 27405.0, -20895.0, 117705.0, 41475.0, -163800.0, -14595.0, 6405.0, -32025.0, -80325.0, -48825.0, 31605.0, -63525.0, -25725.0, -6825.0, 155400.0, -32025.0, -48825.0, -220500.0, -61425.0, -32025.0, 49827.272727272706, -525.0, 1527.272727272706, -10807.317073170736, 3892.682926829264, 29092.682926829264, -2407.317073170736, 54075.0, 159705.0, 56175.0, 51927.272727272706, 72975.0, -8707.317073170736, 66892.68292682926, 310800.0, -15120.0, 37905.0, 5775.0, 10605.0, -38325.0, 29092.682926829264, 62692.682926829264, -65310.0, 210000.0, 37492.682926829264, 12292.682926829264, 24892.682926829264, 30927.272727272706, 12292.682926829264, 14280.0, -94395.0, -23700.0, -59325.0, 1792.682926829264, 37492.682926829264, 94192.68292682926, 66757.89473684208, -4642.105263157922, -36007.317073170736, 24892.682926829264, -2672.727272727294, -67507.31707317074, -37800.0, -11511.111111111124, 186900.0, -102738.4615384615], "type": "histogram", "uid": "03733bc3-dcf0-4afd-a7d0-4e9b2c754017"}, {"histnorm": "percent", "name": "candidate, DecisionTreeRegressor/eval/sample2: 3d7aa7a8-67ec-11e9-bb9f-fc084a6691eb", "opacity": 0.5, "text": "sample2:last<br>DecisionTreeRegressor/model:3c9c3e30-67ec-11e9-aaa0-fc084a6691eb<br>", "x": [-53316.666666666686, -19472.727272727294, -3500.0, -85350.0, -31005.882352941204, -18200.0, 24383.333333333314, -19716.666666666686, -6407.692307692312, -21107.692307692312, 2100.0, -29531.25, 18792.307692307688, 10392.307692307688, -23207.692307692312, 48168.75, -20250.0, -31607.692307692312, -57272.727272727294, -66450.0, -18900.0, -40007.69230769231, -71507.69230769231, 16800.0, -8531.25, -29531.25, 6300.0, -19031.25, -33600.0, -35466.66666666663, 0.0, 0.0, 1050.0, 0.0, -2100.0, -21107.692307692312, -41790.0, -9450.0, -25307.692307692312, -50190.0, -35700.0, 0.0, -44100.0, 6300.0, 0.0, 37668.75, 58668.75, 56568.75, 18792.307692307688, -131.25, -23450.0, 26600.0, 0.0, -350.0, 24850.0, 14175.0, 14175.0, 0.0, 28087.5, 15487.5, 112 ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("91d35878-7084-485c-886b-45637b26c7cc")) {window._Plotly.Plots.resize(docum

# %% [markdown]
# ### Plot data

# %%
plot.histogram_data(ml_repo, {ml_repo.tree.test_data.sample2() :['last'], ml_repo.tree.training_data.sample1(): ['first','last']}, x_coordinate = 'PTRATIO') #, y_coordinate='MEDV')
# Out:
# <div id="8c4754e4-88ff-4080-a79e-f35e5fd2422b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("8c4754e4-88ff-4080-a79e-f35e5fd2422b")) {
#     Plotly.newPlot("8c4754e4-88ff-4080-a79e-f35e5fd2422b", [{"histnorm": "percent", "name": "sample2: 2c8a1fe2-67ec-11e9-8e1f-fc084a6691eb", "opacity": 0.5, "text": "", "x": [18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 18.399999618530273, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 19.600000381469727, 16.899999618530273, 16.899999618530273, 16.899999618530273, 16.899999618530273, 16.899999618530273, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 15.5, 15.899999618530273, 17.600000381469727, 17.600000381469727, 18.799999237060547, 18.799999237060547, 17.899999618530273, 17.0, 19.700000762939453, 19.700000762939453, 18.299999237060547, 18.299999237060547, 17.0, 22.0, 22.0, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.200000762939453, 20.100000381469727, 20.100000381469727, 20.100000381469727, 20.100000381469727, 20.100000381469727, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 19.200000762939453, 21.0, 21.0, 21.0, 21.0], "type": "histogram", "uid": "1df31480-4f3f-4ca0-8ada-aa527e502368"}, {"histnorm": "percent", "name": "sample1: 19ba488c-67ec-11e9-9e5c-fc084a6691eb", "opacity": 0.5, "text": "", "x": [15.300000190734863, 17.799 ...
