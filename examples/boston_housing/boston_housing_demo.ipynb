# %% [markdown]
# # MLRepo - A Quick Introduction
# In this notebook we give a quick introduction working with the repository and explain the basic priniples.

# %%
#import all things you need to get startes
import time
import pandas as pd
import logging as logging
import pprint
import plotly
plotly.offline.init_notebook_mode(connected=True)

# Here start the repository specific imports
#import pailab.repo as repo
import pailab.memory_handler as memory_handler
from pailab import RepoInfoKey, MeasureConfiguration, MLRepo, DataSet, MLObjectType, FIRST_VERSION, LAST_VERSION
from pailab.job_runner.job_runner import SimpleJobRunner, JobState, SQLiteJobRunner

#You may set the loglevel and log-format here. 
logging.basicConfig(level=logging.FATAL)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Read the data
# As an example machine learning task to ilustrate the way of working with the repository we use the Boston housing data from the  [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.php) where we have applied some preprocessing. The data consists of house prices together with the house features `'RM'`, `'LSTAT'`, and `'PTRATIO'`:
# - `'RM'` is the average number of rooms among homes in the neighborhood.
# - `'LSTAT'` is the percentage of homeowners in the neighborhood considered "lower class" (working poor).
# - `'PTRATIO'` is the ratio of students to teachers in primary and secondary schools in the neighborhood.
# We just read the csv-file containing the data (also in the repository) into a pandas dataframe.

# %%
data = pd.read_csv('housing.csv')

# %% [markdown]
# # Create a new repository
# We first create a new repository for our task. The repository is the central key around all functionality is built. Similar to a repository used for source control in classical software development it contains all data and algorithms needed for the machine learning task. The repository needs storages for
# - scripts containing the machine learning algorithms and interfaces,
# - numerical objects such as arrays and matrices representing data, e.g. input data, data from the valuation of the models,
# - json documents representing parameters, e.g. training parameter, model parameter.
#
# To keep things simple, we just start using in memory storages. Note that the used memory interfaces are except for testing and playing around not be the first choice, since when ending the session, everything will be lost...
#
# In addition to the storages the repository needs a reference to a JobRunner which the platform can use to execute machine learning jobs. For this example we use the most simple one, executing everything sequential in the same thread, the repository runs in.

# %%
handler = memory_handler.RepoObjectMemoryStorage() 
numpy_handler = memory_handler.NumpyMemoryStorage()
ml_repo = MLRepo( user = 'test_user', config=None, numpy_repo=numpy_handler)
job_runner = ml_repo._job_runner

# %% [markdown]
# ## Add a tree
# To navigate in a simple way over all objects, one can add a so-called tree to the repository. The tree allows one to use auto completion to acces objcts and respectiv methods.

# %%
from pailab.tools.tools import MLTree
MLTree.add_tree(ml_repo)

# %% [markdown]
# ## Adding data
# The data in the repository is handled by two different data objects:
# - RawData is the object containing real data.
# - DataSet is the object conaining the logical data, i.e. a reference to a RawData object together with a specification, which data from the RawData will be used. Here, one can specify a fixed version of the underlying RawData object (then changes to the RawData will not affect the derived DataSet) or a fixed or floating subset of the RawData by defininga start and endindex cutting the derived data just out of the original data.
#
# Normally one will add RawData and then define DataSets which are used to train or test a model which is exactly the way shown in the following.

# %%
# Add RawData. A convenient way to add RawData is simply to use the method add on the raw_data collection.
# This method just takes a pandas dataframe and the specification, which columns belong to the input 
#and which to the targets.
ml_repo.tree.raw_data.add('boston_housing', data,  input_variables=['RM', 'LSTAT', 'PTRATIO'], target_variables = ['MEDV'])
# based on the raw data we now define training and test sets
ml_repo.tree.training_data.add('sample1', ml_repo.tree.raw_data.boston_housing(), 0, 300)
ml_repo.tree.test_data.add('sample2', ml_repo.tree.raw_data.boston_housing(), 301, None)

# %%
ml_repo.tree.test_data.sample2.history()
# Out:
# {'3be69d78-23e7-11e9-b8e6-fc084a6691eb': {'RepoInfoKey.AUTHOR': 'test_user',
#   'RepoInfoKey.COMMIT_DATE': '2019-01-29 17:59:26.090762',
#   'RepoInfoKey.COMMIT_MESSAGE': ''},
#  '3eb3ad1e-23e7-11e9-81c2-fc084a6691eb': {'RepoInfoKey.AUTHOR': 'test_user',
#   'RepoInfoKey.COMMIT_DATE': '2019-01-29 17:59:30.789097',
#   'RepoInfoKey.COMMIT_MESSAGE': 'RawData raw_data/boston_housing updated, add DataSets depending om the updated RawData.'}}

# %% [markdown]
# When creating the DataSet we have to set two important informations for the repository, given as a dictionary:
# - The object name. Each object in the repository needs to have a unique name in the repository.
# - The object type which gives. In our example here we say that we specify that the DataSet are training and test data. Note that on can have only one training data object pre repository while the repository can obtain many different test data sets.
#
# Some may wonder what is now stored in *version_list*.
# ** Adding an object (independent if it is a data object or some other object such as a parameter), the object gets a version number and no object will be removed, adding just adds a new version.** The add method returns a dictionary of the object names together with their version number.

# %% [markdown]
# ## Adding a model
# The next step to do machine learning would be to define a model which will be used in the repository. A model consists of the following pieces
# - a skript where the code for the model valuation is defined together with the function name of the evaluation method
# - a skript where the code for the model training is defined together with th function nam of the training method
# - a model parameter object defining the model parameter and which must have implemented the correct interface so that it can be used within the repository (see the documentation on integrating new objects, normally there is not more to do then just simply add *@repo_object_init()* to the line above your *__init__* method)
# - a training parameter object defining training parameters (such as number of optimization steps etc.), if necessary for your algorithms (this oen is optional)
#
# ** SKLearn models as an example**
#
# We do not have to define the pieces defined above, if we use the sklearn module. Instead we can use the externals.sklearn module interfacing
# the sklearn package so that this can be used within the repository. This interface provides a simple method (add_model) to add an arbitrary sklearn model as a model which can be handled by the repository. This method adds a bunch of repo objects to the repository (according to the pieces described above):
# - An object defining the function to be called to evaluate the model
# - An object defining the function to be called to train the model
# - An object defining the model
# - An object defining the model parameter
# For the following we just use a DecisionTree as our model.

# %%
import externals.sklearn_interface as sklearn_interface
from sklearn.tree import DecisionTreeRegressor
sklearn_interface.add_model(ml_repo, DecisionTreeRegressor(), model_param={'max_depth': 5})

# %%
ml_repo.tree.models.DecisionTreeRegressor.model_param.obj.repo_info.get_dictionary()
# Out:
# {'author': 'test_user',
#  'big_objects': [],
#  'category': 'MODEL_PARAM',
#  'classname': 'externals.sklearn_interface.SKLearnModelParam',
#  'commit_date': '2019-01-29 17:59:31.446339',
#  'commit_message': '',
#  'description': None,
#  'modification_info': {},
#  'name': 'DecisionTreeRegressor/model_param',
#  'version': '3f17f6a4-23e7-11e9-9754-fc084a6691eb'}

# %% [markdown]
# ## Train the model
# Now, model taining is very simple, since you have defined training and testing data as well as  methods to value and fit your model and the model parameter.
# So, you can just call *run_training* on the repository, and the training is perfomred automatically.
# The training job is executed via the JobRunner you specified setting up the repository. All method of the repository involving jobs return the job id when adding the job to the JobRunner so that you can control the status of the task and see if it sucessfully finished.

# %%
job_id = ml_repo.run_training() 
#job_info = job_runner.get_info(job_id[0], job_id[1])

# %% [markdown]
# ## Run evaluation
# To measure errors and to provide plots the model must be evaluated on all test and training datasets.

# %%
job_id = ml_repo.run_evaluation()

# %% [markdown]
# ## Add and compute measures

# %%
ml_repo.add_measure(MeasureConfiguration.MAX)
ml_repo.add_measure(MeasureConfiguration.R2)

# %%
job_ids = ml_repo.run_measures()

# %%
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.load()
print(str(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.max.obj.value))
# Out:
# 223200.0

# %% [markdown]
# Note that the steps
# - *run_evaluation*
# - *run_measures*
#
# are not necessary if *run_training* is called with the keyword argument *run_descendants=True*.
# In This case the repository would have automatically triggered all evaluations and measurement calculations automatically.

# %% [markdown]
# # Working with the repository
# This section shows how one can work with the audit and revision functionality of the repository.

# %%
for k in MLObjectType:
    names = ml_repo.get_names(k.value)
    for n in names: 
        print(n + '\t  ' + k.value)
# Out:
# DecisionTreeRegressor/eval/sample2	  EVAL_DATA
# DecisionTreeRegressor/eval/sample1	  EVAL_DATA
# raw_data/boston_housing	  RAW_DATA
# sample1	  TRAINING_DATA
# sample2	  TEST_DATA
# DecisionTreeRegressor/model_param	  MODEL_PARAM
# train_sklearn	  TRAINING_FUNCTION
# eval_sklearn	  MODEL_EVAL_FUNCTION
# DecisionTreeRegressor	  MODEL
# DecisionTreeRegressor/model	  CALIBRATED_MODEL
# CommitInfo	  COMMIT_INFO
# repo_mapping	  MAPPING
# DecisionTreeRegressor/measure/sample2/max	  MEASURE
# DecisionTreeRegressor/measure/sample2/r2	  MEASURE
# DecisionTreeRegressor/measure/sample1/max	  MEASURE
# DecisionTreeRegressor/measure/sample1/r2	  MEASURE
# measure_config	  MEASURE_CONFIGURATION
# DecisionTreeRegressor/jobs/training	  JOB
# DecisionTreeRegressor/model/jobs/eval_job/sample2	  JOB
# DecisionTreeRegressor/model/jobs/eval_job/sample1	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample2/max	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample2/r2	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample1/max	  JOB
# DecisionTreeRegressor/model/jobs/measure/sample1/r2	  JOB

# %% [markdown]
# Repository information such as version number, author, date of change are attached to the repo objects and can simply be retrieved:

# %%
ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.load()
pprint.pprint(ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.r2.obj.repo_info.get_dictionary())
# Out:
# {'author': 'test_user',
#  'big_objects': set(),
#  'category': 'MEASURE',
#  'classname': 'pailab.repo_objects.Measure',
#  'commit_date': '2019-01-29 17:59:29.687957',
#  'commit_message': 'computing  measure r2 on data sample1',
#  'description': None,
#  'modification_info': {'DecisionTreeRegressor': '3dee5493-23e7-11e9-b7fc-fc084a6691eb',
#                        'DecisionTreeRegressor/eval/sample1': '3dfaea68-23e7-11e9-98bf-fc084a6691eb',
#                        'DecisionTreeRegressor/model': '3df0bcd5-23e7-11e9-9484-fc084a6691eb',
#                        'DecisionTreeRegressor/model_param': '3dee5492-23e7-11e9-9640-fc084a6691eb',
#                        'eval_sklearn': '3dee5490-23e7-11e9-9a97-fc084a6691eb',
#                        'sample1': '3be67680-23e7-11e9-a5b1-fc084a6691eb',
#                        'train_sklearn': '3dee5491-23e7-11e9-a538-fc084a6691eb'},
#  'name': 'DecisionTreeRegressor/measure/sample1/r2',
#  'version': '3e0ba7d4-23e7-11e9-9e93-fc084a6691eb'}

# %% [markdown]
# The commits can also be queried and printed.

# %%
for k in ml_repo.get_commits():
    pprint.pprint(k.to_dict())
# Out:
# {'author': 'test_user',
#  'message': 'data raw_data/boston_housing added to repository',
#  'objects': {'raw_data/boston_housing': '3be64f92-23e7-11e9-a98f-fc084a6691eb',
#              'repo_mapping': '3be64f92-23e7-11e9-a98f-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 26, 88768)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'repo_mapping': '3be67680-23e7-11e9-a5b1-fc084a6691eb',
#              'sample1': '3be67680-23e7-11e9-a5b1-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 26, 89765)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'repo_mapping': '3be69d78-23e7-11e9-b8e6-fc084a6691eb',
#              'sample2': '3be69d78-23e7-11e9-b8e6-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 26, 90762)}
# {'author': 'test_user',
#  'message': 'add model evaluation function eval_sklearn',
#  'objects': {'eval_sklearn': '3dee5490-23e7-11e9-9a97-fc084a6691eb',
#              'repo_mapping': '3dee5490-23e7-11e9-9a97-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 495771)}
# {'author': 'test_user',
#  'message': 'add model training function train_sklearn',
#  'objects': {'repo_mapping': '3dee5491-23e7-11e9-a538-fc084a6691eb',
#              'train_sklearn': '3dee5491-23e7-11e9-a538-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 495771)}
# {'author': 'test_user',
#  'message': 'adding model and training parameter',
#  'objects': {'DecisionTreeRegressor/model_param': '3dee5492-23e7-11e9-9640-fc084a6691eb',
#              'repo_mapping': '3dee5492-23e7-11e9-9640-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 495771)}
# {'author': 'test_user',
#  'message': 'add model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor': '3dee5493-23e7-11e9-b7fc-fc084a6691eb',
#              'repo_mapping': '3dee5493-23e7-11e9-b7fc-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 495771)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/jobs/training': '3df0bcd4-23e7-11e9-9645-fc084a6691eb',
#              'repo_mapping': '3df0bcd4-23e7-11e9-9645-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 511547)}
# {'author': 'test_user',
#  'message': 'training of model DecisionTreeRegressor',
#  'objects': {'DecisionTreeRegressor/model': '3df0bcd5-23e7-11e9-9484-fc084a6691eb',
#              'repo_mapping': '3df0bcd5-23e7-11e9-9484-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 511547)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample2': '3dfa00a8-23e7-11e9-971b-fc084a6691eb',
#              'repo_mapping': '3dfa00a8-23e7-11e9-971b-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 572266)}
# {'author': 'test_user',
#  'message': 'evaluate data sample2 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample2': '3dfa4f94-23e7-11e9-875b-fc084a6691eb',
#              'repo_mapping': '3dfa4f94-23e7-11e9-875b-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 574286)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/eval_job/sample1': '3dfa7636-23e7-11e9-8445-fc084a6691eb',
#              'repo_mapping': '3dfa7636-23e7-11e9-8445-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 575275)}
# {'author': 'test_user',
#  'message': 'evaluate data sample1 with model DecisionTreeRegressor/model',
#  'objects': {'DecisionTreeRegressor/eval/sample1': '3dfaea68-23e7-11e9-98bf-fc084a6691eb',
#              'repo_mapping': '3dfaea68-23e7-11e9-98bf-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 578250)}
# {'author': 'test_user',
#  'message': 'added measure max for coordinates all',
#  'objects': {'measure_config': '3e02ad54-23e7-11e9-b1cd-fc084a6691eb',
#              'repo_mapping': '3e02ad54-23e7-11e9-b1cd-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 630114)}
# {'author': 'test_user',
#  'message': 'added measure r2 for coordinates all',
#  'objects': {'measure_config': '3e02d454-23e7-11e9-a2a2-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 630114)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/max': '3e0a7030-23e7-11e9-b57d-fc084a6691eb',
#              'repo_mapping': '3e0a7030-23e7-11e9-b57d-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 680976)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/max': '3e0abe14-23e7-11e9-9f57-fc084a6691eb',
#              'repo_mapping': '3e0abe14-23e7-11e9-9f57-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 681973)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample2/r2': '3e0abe15-23e7-11e9-bcf7-fc084a6691eb',
#              'repo_mapping': '3e0abe15-23e7-11e9-bcf7-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 682970)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample2',
#  'objects': {'DecisionTreeRegressor/measure/sample2/r2': '3e0b0bfe-23e7-11e9-a3c2-fc084a6691eb',
#              'repo_mapping': '3e0b0bfe-23e7-11e9-a3c2-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 683967)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/max': '3e0b32fa-23e7-11e9-abb2-fc084a6691eb',
#              'repo_mapping': '3e0b32fa-23e7-11e9-abb2-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 684965)}
# {'author': 'test_user',
#  'message': 'computing  measure max on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/max': '3e0b59ee-23e7-11e9-9306-fc084a6691eb',
#              'repo_mapping': '3e0b59ee-23e7-11e9-9306-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 685962)}
# {'author': 'test_user',
#  'message': '',
#  'objects': {'DecisionTreeRegressor/model/jobs/measure/sample1/r2': '3e0b80de-23e7-11e9-897e-fc084a6691eb',
#              'repo_mapping': '3e0b80de-23e7-11e9-897e-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 686959)}
# {'author': 'test_user',
#  'message': 'computing  measure r2 on data sample1',
#  'objects': {'DecisionTreeRegressor/measure/sample1/r2': '3e0ba7d4-23e7-11e9-9e93-fc084a6691eb',
#              'repo_mapping': '3e0ba7d4-23e7-11e9-9e93-fc084a6691eb'},
#  'time': datetime.datetime(2019, 1, 29, 17, 59, 29, 688954)}

# %% [markdown]
# ## Labeling models
# There is the possibility to label a certain version of a model. The label can then be used to access the model instead of the version number. It is vry useful to
# compare e.g. the current productive model (labeld e.g. 'prod') against other model versions. abels are supported by many functions and tools and make life much easier. So the consistency checks only check for the latest and labeled models if there are changes make a rerun of training/evaluation/measures needed. Also som figures will automatically highlight the results belonging to labeled versions.
#
# Let us label the latest model version in the repo.

# %%
ml_repo.tree.models.DecisionTreeRegressor.set_label('prod',version = LAST_VERSION, message='we found our first production model')

# %% [markdown]
# ## Tests
# It is possible to define model tests.
# ### Regressiontests
# Regressiontests compare measuresments on the repositories dataset of a model to th measurements of labeled reference model.

# %%
import pailab.tests
reg_test = pailab.tests.RegressionTestDefinition(reference='prod', models=None, data=None, labels=None, measures=None,  tol=1e-3)
reg_test.repo_info.name='reg_test'
#reg_test.repo_info.category = MLObjectType.TEST_DEFINITION
ml_repo.add(reg_test, message='regression test definition')
#ml_repo.tree.models.DecisionTreeRegressor.measures.sample1.
# Out:
# '3e402874-23e7-11e9-bfe5-fc084a6691eb'

# %%
ml_repo.run_tests()
# Out:
# [('DecisionTreeRegressor/tests/reg_test/sample2',
#   '570da692-23e9-11e9-9cb4-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample3',
#   '570df47a-23e9-11e9-a82d-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '570e6962-23e9-11e9-bb70-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample2',
#   '570f2d24-23e9-11e9-a920-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample3',
#   '570feff8-23e9-11e9-a0c8-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '57108ac2-23e9-11e9-af16-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample2',
#   '5711268a-23e9-11e9-be9d-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample3',
#   '57119b68-23e9-11e9-a807-fc084a6691eb'),
#  ('DecisionTreeRegressor/tests/reg_test/sample1',
#   '57121062-23e9-11e9-b717-fc084a6691eb')]

# %% [markdown]
# ## Consistency checks
# Pailab's *checks*-submodule provides functionality to check for consistency and quality issues as well as for outstanding tasks (such as rerunning a training after the training set has been changed).
#
# ### Model consistency
# There are different checks to test model consistency such as if the tests of a model are up to date and succeeded or if the latest model is trained on the latest trainin data. All model tests are performed for **labeled** models and the latest model only.
# In our first example we change a model parameter but do not train for a new model version wih this parameter.
#
# The following checks are performed:
# - Is the latest model calibrated on the latest parameters and training data
# - Are all labeled models (including latest model) evaluated on the latest available training and test data
# - Are all measures of all labeled models computed on the latest data
# - Have all tests been run on the labeled models

# %%
param = ml_repo.get('DecisionTreeRegressor/model_param')
param.sklearn_params['max_depth'] = 2
version = ml_repo.add(param)
print(param.sklearn_params)
# Out:
# {'criterion': 'mse', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': False, 'random_state': None, 'splitter': 'best'}

# %% [markdown]
# After we have changed the model parameter, we use the *tools* submodules *check_model* method for open tasks/inconsistencies. This method can be called for a certain model or also for a lbeled model. If nothing is specified, all labeled models will be checked.
# Applying the method to the latest model we see that the output shows that the models last version has been calibrated using a different model parameter version then the current version.

# %%
import pailab.tools.checker as checker
results = checker.run(ml_repo)
pprint.pprint(results)
# Out:
# [{'DecisionTreeRegressor/model:last': {'latest model version not on latest inputs': {'DecisionTreeRegressor/model_param': {'latest version': '3e4eeb66-23e7-11e9-95c6-fc084a6691eb',
#                                                                                                                            'modifier version': '3dee5492-23e7-11e9-9640-fc084a6691eb'}}}}]

# %% [markdown]
# Note that the labeled model would not show an issue. Only the latest model is affected by this change (it is the definition of latest model that it has been calibrated on latest inputs).
#
# We can resolve this issue by simply training the model again (now on the new training data set).

# %%
ml_repo.run_training()
# Out:
# ('DecisionTreeRegressor/jobs/training', '3e5e747e-23e7-11e9-978c-fc084a6691eb')

# %% [markdown]
# Note that the solution to simply retrain introduced new issues: The model has not yet been evaluated and no measures have been computed. (If we would have set **run_descendants=False** as argument, the preceding steps would have also been performed and the issues would not have been present).

# %%
results = checker.run(ml_repo)
pprint.pprint(results)
# Out:
# [{'DecisionTreeRegressor/model:last': {'evaluations missing': {'sample1': '3be67680-23e7-11e9-a5b1-fc084a6691eb',
#                                                                'sample2': '3be69d78-23e7-11e9-b8e6-fc084a6691eb'},
#                                        'measures not calculated': {'DecisionTreeRegressor/measure/sample1/max',
#                                                                    'DecisionTreeRegressor/measure/sample1/r2',
#                                                                    'DecisionTreeRegressor/measure/sample2/max',
#                                                                    'DecisionTreeRegressor/measure/sample2/r2'}}}]

# %%
ml_repo.run_evaluation(run_descendants=True)# we use run_descendants so that the issues with th measures are resolved too
# Out:
# [('DecisionTreeRegressor/model/jobs/eval_job/sample2',
#   '3e6ff4ae-23e7-11e9-abaf-fc084a6691eb'),
#  ('DecisionTreeRegressor/model/jobs/eval_job/sample1',
#   '3e710564-23e7-11e9-a72a-fc084a6691eb')]

# %%
results = checker.run(ml_repo)
pprint.pprint(results)
# Out:
# []

# %% [markdown]
# ### Checking training and test data consistency
# There may be also data inconsistencies, so for example the training and test data overlap. The **check_data** methods performs such a test.
#
# Let us first add a new test data set which overlaps with the training data

# %%
ml_repo.tree.test_data.add('sample3', ml_repo.tree.raw_data.boston_housing(), 0, 50)

# %%
checker.run(ml_repo)
# Out:
# [{'DecisionTreeRegressor/model:last': {'evaluations missing': {'sample3': '3e8237ae-23e7-11e9-b930-fc084a6691eb'},
#    'measures not calculated': {'DecisionTreeRegressor/measure/sample3/max',
#     'DecisionTreeRegressor/measure/sample3/r2'}}},
#  {'prod': {'evaluations missing': {'sample3': '3e8237ae-23e7-11e9-b930-fc084a6691eb'},
#    'measures not calculated': {'DecisionTreeRegressor/measure/sample3/max',
#     'DecisionTreeRegressor/measure/sample3/r2'}}},
#  {'sample3': {'training and test data overlap': {'sample1': '3be67680-23e7-11e9-a5b1-fc084a6691eb',
#     'sample3': '3e8237ae-23e7-11e9-b930-fc084a6691eb'}}}]

# %% [markdown]
# ### Checking usage of RawData
# The check_data method includes also a check if all RawData is used in DataSets or if there is some unused data.

# %% [markdown]
# ### Checking test status
# There is also a check if all latest tests have been applied to all labeled models and all latest models.

# %%
checker.Tests.run(ml_repo)
#depp = ml_repo.get('DecisionTreeRegressor/tests/reg_test/sample1')
#depp.repo_info.commit_date
# Out:
# {'DecisionTreeRegressor/model:3e5ee958-23e7-11e9-b639-fc084a6691eb': {'DecisionTreeRegressor/tests/reg_test/sample1': 'Test for model DecisionTreeRegressor/model, version 3e5ee958-23e7-11e9-b639-fc084a6691eb on latest data sample1 missing.',
#   'DecisionTreeRegressor/tests/reg_test/sample2': 'Test for model DecisionTreeRegressor/model, version 3e5ee958-23e7-11e9-b639-fc084a6691eb on latest data sample2 missing.',
#   'DecisionTreeRegressor/tests/reg_test/sample3': 'Test for model DecisionTreeRegressor/model, version 3e5ee958-23e7-11e9-b639-fc084a6691eb on latest data sample3 missing.'},
#  'DecisionTreeRegressor/model:prod': {'DecisionTreeRegressor/tests/reg_test/sample3': 'Test for model DecisionTreeRegressor/model, version 3df0bcd5-23e7-11e9-9484-fc084a6691eb on latest data sample3 missing.'}}

# %% [markdown]
# ## Easy access to repo objects and names
# Since the names are chosen equally to a directory structure (with subdirectories) they may be long and difficult to remember (especially the order). And even if one remembers the long names, it is a lot of work to type them.

# %% [markdown]
# If you now type the objects name followd by a '.' by pressing tab you will see the possible next solutions makin it very easy to 'browse' to the object's name you have in mind. By using '()' operator you get a list of names below th current naming level, and in addition you can filter the names by giving a string: Only names containing this string are put into the list.

# %%
ml_repo.tree.models.DecisionTreeRegressor.model_param.load()

# %%
ml_repo.tree.models.DecisionTreeRegressor.model_param.obj.repo_info.get_dictionary()
# Out:
# {'author': 'test_user',
#  'big_objects': [],
#  'category': 'MODEL_PARAM',
#  'classname': 'externals.sklearn_interface.SKLearnModelParam',
#  'commit_date': '2019-01-29 17:59:30.128778',
#  'commit_message': '',
#  'description': None,
#  'modification_info': {},
#  'name': 'DecisionTreeRegressor/model_param',
#  'version': '3e4eeb66-23e7-11e9-95c6-fc084a6691eb'}

# %% [markdown]
# ## Append RawData
# One can append data to the RawData object. The repository manages which objects are affected by appending data and directly updates these objects.

# %%
train_data = ml_repo.get_training_data(full_object = False)
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data))
test_data = ml_repo.get_names(MLObjectType.TEST_DATA)
for k in test_data:
    t = ml_repo.get(k)
    print(str(t)+ ' Version: ' + str(t.repo_info[RepoInfoKey.VERSION]))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489}
# {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 3be69d78-23e7-11e9-b8e6-fc084a6691eb
# {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489} Version: 3e8237ae-23e7-11e9-b930-fc084a6691eb

# %%
from numpy import array
ml_repo.tree.raw_data.boston_housing.append(x_data = array([[ 6.575, 4.98, 15.3]]), y_data =array([[504000.0]]))

# %%
print(train_data.repo_info[RepoInfoKey.NAME] +': ' +str(train_data))
for k in test_data:
    t = ml_repo.get(k)
    print(str(t) + ' Version: ' + str(t.repo_info[RepoInfoKey.VERSION]))
# Out:
# sample1: {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 300, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 489}
# {'raw_data': 'raw_data/boston_housing', 'start_index': 301, 'end_index': None, 'raw_data_version': '3eb2ea52-23e7-11e9-98c5-fc084a6691eb', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb
# {'raw_data': 'raw_data/boston_housing', 'start_index': 0, 'end_index': 50, 'raw_data_version': 'last', 'x_coord_names': ['RM', 'LSTAT', 'PTRATIO'], 'y_coord_names': ['MEDV'], 'n_data': 490} Version: 3e8237ae-23e7-11e9-b930-fc084a6691eb

# %%
results = checker.run(ml_repo)
print(results)
# Out:
# [{'DecisionTreeRegressor/model:last': {'evaluations missing': {'sample2': '3eb3ad1e-23e7-11e9-81c2-fc084a6691eb', 'sample3': '3e8237ae-23e7-11e9-b930-fc084a6691eb'}, 'measures not calculated': {'DecisionTreeRegressor/measure/sample3/max', 'DecisionTreeRegressor/measure/sample3/r2'}}}, {'prod': {'evaluations missing': {'sample2': '3eb3ad1e-23e7-11e9-81c2-fc084a6691eb', 'sample3': '3e8237ae-23e7-11e9-b930-fc084a6691eb'}, 'measures not calculated': {'DecisionTreeRegressor/measure/sample3/max', 'DecisionTreeRegressor/measure/sample3/r2'}}}, {'sample3': {'training and test data overlap': {'sample3': '3e8237ae-23e7-11e9-b930-fc084a6691eb', 'sample1': '3be67680-23e7-11e9-a5b1-fc084a6691eb'}}}]

# %% [markdown]
# # Repo-Analysis
# Having parameters, evaluations, measures in one place enables out of the box analysis- and plotting functionality. The submodule *plot* provides automated, standardized plots.

# %%
import pailab.analysis.plot as plot
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Plotting
# ### Plot errors and measures

# %%
# create more different model params etc. to make the repo more interesting ;-)
for j in range(2):
    training_data = ml_repo.get(ml_repo.tree.training_data.sample1())
    training_data.end_index += 50
    ml_repo.add(training_data, message='add 50 datapoints to end_index')
    for i in range(6,12):
        #print(i)
        param = ml_repo.get(ml_repo.tree.models.DecisionTreeRegressor.model_param())
        param.sklearn_params['max_depth'] = i
        version = ml_repo.add(param)
        ml_repo.add(param)
        ml_repo.run_training()
        ml_repo.run_evaluation()
        ml_repo.run_measures()
        if j == 1 and i==6:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('prod', message='')
        if j == 1 and i==8:
            ml_repo.tree.models.DecisionTreeRegressor.set_label('candidate', message='')

# %% [markdown]
# #### Plot error measure vs parameter

# %%
import pailab.analysis.plot_helper as plt_helper
import pailab.analysis.plot as plot
plot.measure_by_parameter(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.measures('r2'), 'max_depth', data_versions=LAST_VERSION)
#ml_repo.models.DecisionTreeRegressor.measures('r2')
# Out:
# <div id="98022300-4975-476b-92f6-97d7b3a015c2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("98022300-4975-476b-92f6-97d7b3a015c2", [{"type": "scatter", "x": [6, 7, 8, 9, 10, 11, 6, 7, 8, 9, 10, 11], "y": [-0.1788927717411688, -0.007893962503640717, 0.0016986856585989862, 0.003978541850712891, -0.012602609131632914, -0.00943722341792097, 0.6019705131805051, 0.6087111999865398, 0.6146563614786593, 0.6132097912139078, 0.6150848256569403, 0.6293524353374513], "text": ["model version: 3ed68680-23e7-11e9-95ce-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3ed59ccc-23e7-11e9-a3d4-fc084a6691eb", "model version: 3edd38ac-23e7-11e9-a029-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3ed59ccc-23e7-11e9-a3d4-fc084a6691eb", "model version: 3ee1f06c-23e7-11e9-be39-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3ed59ccc-23e7-11e9-a3d4-fc084a6691eb", "model version: 3ee743f6-23e7-11e9-80c9-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3ed59ccc-23e7-11e9-a3d4-fc084a6691eb", "model version: 3eece56c-23e7-11e9-b3d5-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3ed59ccc-23e7-11e9-a3d4-fc084a6691eb", "model version: 3ef3e58a-23e7-11e9-8603-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3ed59ccc-23e7-11e9-a3d4-fc084a6691eb", "model version: 3efda2dc-23e7-11e9-ac02-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f039238-23e7-11e9-b091-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f08e5c6-23e7-11e9-9906-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f0e393e-23e7-11e9-8e1d-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f1317f6-23e7-11e9-b94b-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f189262-23e7-11e9-b49c-fc084a6691eb<br>sample3: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb"], "name": "DecisionTreeRegressor/measure/sample2/r2: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb", "mode": "markers"}, {"type": "scatter", "x": [6, 7, 8, 9, 10, 11], "y": [0.9206555170571403, 0.943222990674039, 0.9607011084516344, 0.9731471291827914, 0.9820532944820078, 0.9890984174845654], "text": ["model version: 3efda2dc-23e7-11e9-ac02-fc084a6691eb<br>sample3: 3efce00c-23e7-11e9-925e-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f039238-23e7-11e9-b091-fc084a6691eb<br>sample3: 3efce00c-23e7-11e9-925e-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f08e5c6-23e7-11e9-9906-fc084a6691eb<br>sample3: 3efce00c-23e7-11e9-925e-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f0e393e-23e7-11e9-8e1d-fc084a6691eb<br>sample3: 3efce00c-23e7-11e9-925e-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f1317f6-23e7-11e9-b94b-fc084a6691eb<br>sample3: 3efce00c-23e7-11e9-925e-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb", "model version: 3f189262-23e7-11e9-b49c-fc084a6691eb<br>sample3: 3efce00c-23e7-11e9-925e-fc084a6691eb<br>train_data: 3efce00c-23e7-11e9-925e-fc084a6691eb"], "name": "DecisionTreeRegressor/measure/sample1/r2: 3efce00c-23e7-11e9-925e-fc084a6691eb", "mode": "markers"}, {"type": "scatter", "x": [6, 7, 8, 9, 10, 11, 6, 7, 8, 9, 10, 11], "y": [0.8966810082660464, 0.9262597226158051, 0.968168187912 ...

# %% [markdown]
# #### Plot error vs input variable

# %%
plot.scatter_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ml_repo.tree.test_data.sample2(), 'PTRATIO')
# Out:
# <div id="998fe4aa-e66a-4951-b084-ec790f3483a7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("998fe4aa-e66a-4951-b084-ec790f3483a7", [{"type": "scatter", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0, 21.0, 21.0], "y": [21675.0, -8040.0, -42329.4117647059, 350.0, -75240.0, -44542.10526315792, -31733.333333333314, 47376.0, 3276.0, 3870.588235294097, -10829.411764705903, -14025.0, -26940.0, 29070.588235294097, 20670.588235294097, -12929.411764705903, 50760.0, -54390.0, -21329.411764705903, -80129.4117647059, -100590.0, -35025.0, -29729.411764705903, -61229.4117647059, 675.0, -5940.0, -26940.0, -9825.0, -16440.0, -49725.0, -34700.0, -149429.4117647059, -60243.75, -14700.0, -47940.0, -54240.0, -10829.411764705903, -47643.75, -17100.0, -15029.411764705903, 6650.0, -51825.0, -37800.0, -60225.0, -9825.0, 28875.0, 17976.0, 38976.0, 36876.0, 29070.588235294097, -19824.0, 21360.0, 26600.0, 0.0, 44460.0, 69660.0, 74760.0, 74760.0, 0.0, -34650.0, 0.0, 60060.0, -840.0, 0.0, 13860.0, 22260.0, 43260.0, -30240.0, -63840.0, 5460.0, -59640.0, -840.0, 26460.0, 12180.0, 0.0, -11340.0, -36400.0, -78225.0, -69825.0, 47460.0, -36540.0, -110040.0, -82740.0, -97440.0, -63840.0, 39060.0, -40740.0, -36540.0, -110040.0, 34860.0, 170460.0, 146160.0, 57750.0, -100440.0, 34650.0, 160860.0, 127260.0, -68040.0, -63840.0, -121800.0, 3360.0, -30240.0, -343350.0, 24500.0, -28000.0, 21360.0, 66360.0, -59220.0, -40740.0, -112000.0, -97300.0, 15960.0, -15540.0, -40425.0, -223650.0, -99624.0, -44625.0, -80500.0, -45150.0, -143325.0, -32340.0, -38640.0, 53760.0, 5460.0, 144060.0, 41475.0, -163800.0, 11760.0, 32760.0, -32025.0, -80325.0, -48825.0, 57960.0, 2100.0, -25725.0, -6825.0, 58800.0, 33600.0, -48825.0, -220500.0, -61425.0, -32025.0, 93800.0, -525.0, 45500.0, -28224.0, -13524.0, 11676.0, 2460.0, 54075.0, 186060.0, 56175.0, 95900.0, 72975.0, -26124.0, 49476.0, 407400.0, -15120.0, 64260.0, 5775.0, 36960.0, -38325.0, 11676.0, 45276.0, -78000.0, -146868.75, 42360.0, 17160.0, 7476.0, 74900.0, 17160.0, 14280.0, -68040.0, -44940.0, -59325.0, 6660.0, 42360.0, 99060.0, 66757.89473684208, -4642.105263157922, -31140.0, 29760.0, -80033.33333333331, -62640.0, -91743.75, -9825.0, -169968.75, -113700.0], "text": "sample2:last<br>DecisionTreeRegressor/model:3efda2dc-23e7-11e9-ac02-fc084a6691eb<br>", "name": "prod, DecisionTreeRegressor/eval/sample2: 3efe3ea2-23e7-11e9-a3c4-fc084a6691eb", "mode": "markers"}, {"type": "scatter", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20. ...

# %% [markdown]
# #### Plot histogram of model error

# %%
plot.histogram_model_error(ml_repo, ml_repo.tree.models.DecisionTreeRegressor.model(), ml_repo.tree.test_data.sample2())
# Out:
# <div id="1a5635bf-4742-4bfc-ba4b-3acb9ccf5e87" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1a5635bf-4742-4bfc-ba4b-3acb9ccf5e87", [{"type": "histogram", "x": [21675.0, -8040.0, -42329.4117647059, 350.0, -75240.0, -44542.10526315792, -31733.333333333314, 47376.0, 3276.0, 3870.588235294097, -10829.411764705903, -14025.0, -26940.0, 29070.588235294097, 20670.588235294097, -12929.411764705903, 50760.0, -54390.0, -21329.411764705903, -80129.4117647059, -100590.0, -35025.0, -29729.411764705903, -61229.4117647059, 675.0, -5940.0, -26940.0, -9825.0, -16440.0, -49725.0, -34700.0, -149429.4117647059, -60243.75, -14700.0, -47940.0, -54240.0, -10829.411764705903, -47643.75, -17100.0, -15029.411764705903, 6650.0, -51825.0, -37800.0, -60225.0, -9825.0, 28875.0, 17976.0, 38976.0, 36876.0, 29070.588235294097, -19824.0, 21360.0, 26600.0, 0.0, 44460.0, 69660.0, 74760.0, 74760.0, 0.0, -34650.0, 0.0, 60060.0, -840.0, 0.0, 13860.0, 22260.0, 43260.0, -30240.0, -63840.0, 5460.0, -59640.0, -840.0, 26460.0, 12180.0, 0.0, -11340.0, -36400.0, -78225.0, -69825.0, 47460.0, -36540.0, -110040.0, -82740.0, -97440.0, -63840.0, 39060.0, -40740.0, -36540.0, -110040.0, 34860.0, 170460.0, 146160.0, 57750.0, -100440.0, 34650.0, 160860.0, 127260.0, -68040.0, -63840.0, -121800.0, 3360.0, -30240.0, -343350.0, 24500.0, -28000.0, 21360.0, 66360.0, -59220.0, -40740.0, -112000.0, -97300.0, 15960.0, -15540.0, -40425.0, -223650.0, -99624.0, -44625.0, -80500.0, -45150.0, -143325.0, -32340.0, -38640.0, 53760.0, 5460.0, 144060.0, 41475.0, -163800.0, 11760.0, 32760.0, -32025.0, -80325.0, -48825.0, 57960.0, 2100.0, -25725.0, -6825.0, 58800.0, 33600.0, -48825.0, -220500.0, -61425.0, -32025.0, 93800.0, -525.0, 45500.0, -28224.0, -13524.0, 11676.0, 2460.0, 54075.0, 186060.0, 56175.0, 95900.0, 72975.0, -26124.0, 49476.0, 407400.0, -15120.0, 64260.0, 5775.0, 36960.0, -38325.0, 11676.0, 45276.0, -78000.0, -146868.75, 42360.0, 17160.0, 7476.0, 74900.0, 17160.0, 14280.0, -68040.0, -44940.0, -59325.0, 6660.0, 42360.0, 99060.0, 66757.89473684208, -4642.105263157922, -31140.0, 29760.0, -80033.33333333331, -62640.0, -91743.75, -9825.0, -169968.75, -113700.0], "text": "sample2:last<br>DecisionTreeRegressor/model:3efda2dc-23e7-11e9-ac02-fc084a6691eb<br>", "name": "prod, DecisionTreeRegressor/eval/sample2: 3efe3ea2-23e7-11e9-a3c4-fc084a6691eb", "opacity": 0.5}, {"type": "histogram", "x": [-17500.0, 17850.0, -19472.727272727294, -3675.0, -49350.0, -31005.882352941204, -6300.0, 21787.5, 7700.0, -6407.692307692312, -21107.692307692312, 3829.411764705903, -40600.0, 18792.307692307688, 10392.307692307688, -23207.692307692312, 37100.0, -37247.36842105264, -31607.692307692312, -57272.727272727294, -83447.36842105264, -17170.588235294097, -40007.69230769231, -71507.69230769231, 18529.411764705903, -19600.0, -40600.0, 8029.411764705903, -30100.0, -31870.588235294097, -38563.63636363635, 0.0, -35910.0, 9975.0, -61600.0, -67900.0, -21107.692307692312, -23310.0, 1050.0, -25307.692307692312, 2625.0, -33970.5882352941, -13125.0, -42370.5882352941, 8029.411764705903, 0.0, 22400.0, 13387.5, 41300.0, 18792.307692307688, -15400.0, 7700.0, 0.0, 0.0, 30800.0, 56000.0, 47600.0, 47600.0, 0.0, 0.0, 0.0, 41475.0, -19425.0, 0.0, -4725.0, 3675.0, 24675.0, 23730.0, -9870.0, 59430.0, -5670.0, 53130.0, 7875.0, -11550.0, 0.0, -29925.0, 0.0, -4200.0, 4200.0, 28875.0, -55125.0, -56070.0, -28770.0, -43470.0, -82425.0, 20475.0, -59325.0, 17430.0, -128625.0, 16275.0, 156800.0, 127575.0, 0.0, -114100.0, 0.0, 0.0, 108675.0, -95200.0, -9870.0, -121800.0, 57330.0, -48825.0, -401100.0, 60900.0, 8400.0, 7700.0, 47775.0, -50400.0, -59325.0, -75600.0, -107100.0, -2625.0, -34125.0, -69300.0, -281400.0, -60900.0, 29400.0, -44100.0, -10500.0, -172200.0, -50925.0, -199500.0, 35175.0, -13125.0, 125475.0, 115500.0, -163800.0, -6825.0, 14175.0, -60900.0 ...

# %% [markdown]
# ### Plot data

# %%
plot.histogram_data(ml_repo, {ml_repo.tree.test_data.sample2() :['last'], ml_repo.tree.training_data.sample1(): ['first','last']}, x_coordinate = 'PTRATIO') #, y_coordinate='MEDV')
# Out:
# <div id="6c1b8aad-4e24-4b9d-87f2-461ab2c0b935" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6c1b8aad-4e24-4b9d-87f2-461ab2c0b935", [{"type": "histogram", "x": [18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 19.6, 16.9, 16.9, 16.9, 16.9, 16.9, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 15.5, 15.9, 17.6, 17.6, 18.8, 18.8, 17.9, 17.0, 19.7, 19.7, 18.3, 18.3, 17.0, 22.0, 22.0, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.2, 20.1, 20.1, 20.1, 20.1, 20.1, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 19.2, 21.0, 21.0, 21.0, 21.0], "text": "", "name": "sample2: 3eb3ad1e-23e7-11e9-81c2-fc084a6691eb", "opacity": 0.5}, {"type": "histogram", "x": [15.3, 15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7, 18.7, 18.7, 18.7, 19.0, 19.0, 19.0, 19.0, 18.5, 18.5, 18.5, 18.5, 17.8, 17.8, 17.8, 17.8, 18.2, 18.2, 18.2, 18.0, 18.0, 18.0, 18.0, 18.0, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 20.9, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 21.2, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 14.7, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 17.8, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.6, 15.6, 12.6, 12.6, 12.6, 17.0, 17.0, 14.7, 14.7, 14.7, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 18.6, 16.4, 16.4, 16.4, 16.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 17.4, 16.6, 16.6, 16.6, 16.6, 16.6, 16.6, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 19.1, 16.4, 16.4, 15.9, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 18.6, 18.6, 18.6, 18.6, 18.6, 17.6, 17.6, 17.6, 17.6, 17.6, 14.9, 14.9, 14.9, 14.9, 15.3, 15.3, 18.2, 16.6, 16.6, 16.6, 19.2, 19.2, 19.2, 16.0, 16.0, 16.0, 16.0, 16.0, 14.8, 14.8, 14.8, 16.1, 16.1, 16.1, 18.4, 18.4, 18.4, 18.4, 18.4, 18.4], "text": "", "name": "sample1: 3be67680-23e7-11e9-a5b1-fc084a6691eb", "opacity": 0.5}, {"type": "histogram", "x": [15.3, 15.3, 17.8, 17.8, 18.7, 18.7, 18.7, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 15.2, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 19.2, 19.2, 19.2, 19.2, 18.3, 18.3, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 17.9, 16.8, 16.8, 16.8, 16.8, 21.1, 17.9, 17.3, 15.1, 19.7, 19.7, 19.7, 19.7, 19.7, 19.7, 18.6, 16.1, 16.1, 18.9, 18.9, 18.9, 19.2, 19.2, 19.2, 19.2, 18.7, 18.7, 18.7, 18.7, 18.7, 18.7, 19.0 ...
